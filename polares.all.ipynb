# %% [markdown]
# ## Use coeficientes CL e Cd From Qblade

# %%
import pandas as pd
import sys
import csv

print(sys.version)
print('pandas version', pd.__version__)
# Out:
# 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:40:32) [GCC 12.3.0]
# pandas version 2.0.3

# %%
 # /kaggle/input/polar-try/E63 # V11

# %% [markdown]
# ## Reading from files ( No edit from Qblade )

# %%
## Carregar banco de dados 

df_cd = pd.read_csv("/kaggle/input/polar-try/E63/esconde_geim/all_cd.txt",delimiter='\t',skiprows=2)
df_cl = pd.read_csv("/kaggle/input/polar-try/E63/esconde_geim/all_cl.txt",delimiter='\t',skiprows=2)
#/kaggle/input/polar-try/Clark Y/esconde_geim/all_cd.txt
#df2 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_4.5e4.txt",delimiter='\t', skiprows=1, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
#df3 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_1e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
#df4 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cd/cd_R_4.5e4.txt",delimiter='\t', skiprows=1)
#df_temp = pd.read_csv('arquivo.csv', nrows=0)
#print(df2.columns)
#df2.head(12)
#df2['cl_next'] = df3.iloc[:, 1]

#print(df.columns)
df_cl.head(6)
#df_cd.head(12)

#print('done')
#df2.head(12)
#/kaggle/input/polar-try/E63
# Out:
#    Angle of Attack [deg]  Lift Coefficient Cl [-] Angle of Attack [deg].1  \
# 0                 -180.0                -0.114214          -1.8000000e+02
# 1                 -179.0                -0.020053          -1.7900000e+02
# 2                 -178.0                 0.073016          -1.7800000e+02
# 3                 -177.0                 0.160244          -1.7700000e+02
# 4                 -176.0                 0.231974          -1.7600000e+02
# 5                 -175.0                 0.278381          -1.7500000e+02
#
#   Lift Coefficient Cl [-].1 Angle of Attack [deg].2 Lift Coefficient Cl [-].2  \
# 0            -2.3014626e-02          -1.8000000e+02            -5.2798279e-02
# 1             1.0249509e+00          -1.7900000e+02             1.6700150e-01
# 2             2.0726833e+00          -1.7800000e+02             3.8623643e-01
# 3             3.0381825e+00          -1.7700000e+02             5.9322411e-01
# 4             3.3310006e+00          -1.7600000e+02             7.4373412e-01
# 5             2.5800693e+00          -1.7500000e+02             7.8167981e-01
#
#   Angle of Attack [deg].3 Lift Coefficient Cl [-].3 Angle of Attack [deg].4  \
# 0          -1.8000000e+02            -5.2402433e-02          -1.8000000e+02
# 1          -1.7900000e+02             1.8063365e-01          -1.7900000e+02
# 2          -1.7800000e+02             4.1247296e-01          -1.7800000e+02
# 3          -1.7700000e+02             6.2615359e-01          -1.7700000e+02
# 4          -1.7600000e+02             7.6838225e-01          -1.7600000e+02
# 5          -1.7500000e+02             7.8580880e-01          -1.7500000e+02
#
#   Lift Coefficient Cl [-].4 Angle of Attack [deg].5 Lift Coefficient Cl [-].5  \
# 0            -8.7264426e-02          -1.8000000e+02            -1.8169907e-01
# 1             1.1271726e-01          -1.7900000e+02            -1.3883393e-01
# 2             2.9061592e-01          -1.7800000e+02            -9.9351719e-02
# 3             4.0968037e-01          -1.7700000e+02            -6.2602013e-02
# 4             4.4857484e-01          -1.7600000e+02            -2.8126257e-02
# 5             4.2883310e-01          -1.7500000e+02             4.3935161e-03
#
#   Angle of Attack [deg].6 Lift Coefficient Cl [-].6 Angle of Attack [deg].7  \
# 0          -1.8000000e+02            -2.0539548e-01          -1.8000000e+02
# 1          -1.7900000e+02            -1.2304242e-01          -1.7900000e+02
# 2          -1.7800000e+02            -5.5150896e-02          -1.7800000e+02
# 3          -1.7700000e+02            -4.4249552e-03          -1.7700000e+02
# 4          -1.7600000e+02             3.1507961e-02          -1.7600000e+02
# 5          -1.7500000e+02             5.7634741e-02          -1.7500000e+02
#
#   Lift Coefficient Cl [-].7 Angle of Attack [deg].8 Lift Coefficient Cl [-].8
# 0            -1.3330780e-01          -4.0000000e+00            -2.3029999e-01
# 1             1.1664793e-02          -3.5000000e+00            -1.4640000e-01
# 2             1.4292437e-01          -3.0000000e+00            -1.8500000e-02
# 3             2.3951663e-01          -2.5000000e+00             8.4100001e-02
# 4             2.8714314e-01          -2.0000000e+00             1.8709999e-01
# 5             2.9391608e-01          -1.5000000e+00             3.1240001e-01

# %%
# Garante que pandas mostre todas as linhas e colunas sem cortar

#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_colwidth', None)

pd.reset_option('display.max_rows')
pd.reset_option('display.max_colwidth')

print(df_cl.iloc[:, [0]])
# Out:
#      Angle of Attack [deg]
# 0                   -180.0
# 1                   -179.0
# 2                   -178.0
# 3                   -177.0
# 4                   -176.0
# ..                     ...
# 365                  176.0
# 366                  177.0
# 367                  178.0
# 368                  179.0
# 369                  180.0
#
# [370 rows x 1 columns]

# %%
# Remover colunas desnecessárias 

columns_to_drop_cd = [
    'Angle of Attack [deg].1',
    'Angle of Attack [deg].2',
    'Angle of Attack [deg].3',
    'Angle of Attack [deg].4',
    'Angle of Attack [deg].5',
    'Angle of Attack [deg].6',
    'Angle of Attack [deg].7',
    'Angle of Attack [deg].8',
    'Drag Coefficient Cd [-].8'
]
#Drag Coefficient Cd [-].8
columns_to_drop_cl = [
    'Angle of Attack [deg].1',
    'Angle of Attack [deg].2',
    'Angle of Attack [deg].3',
    'Angle of Attack [deg].4',
    'Angle of Attack [deg].5',
    'Angle of Attack [deg].6',
    'Angle of Attack [deg].7',
    'Angle of Attack [deg].8',
    'Lift Coefficient Cl [-].8'
]
 
df_cl = df_cl.drop(columns=columns_to_drop_cl, errors='ignore')
df_cd = df_cd.drop(columns=columns_to_drop_cd, errors='ignore')

# Remover linhas desnecessárias 
df_cl = df_cl[df_cl.iloc[:, 0] != 'END']
df_cd = df_cd[df_cd.iloc[:, 0] != 'END']

# Remover linhas onde o valor da primeira coluna termina com .5 (parte decimal igual a 0.5)
df_cl = df_cl[df_cl.iloc[:, 0] % 1 != 0.5]
df_cd = df_cd[df_cd.iloc[:, 0] % 1 != 0.5]

print( 'done')
# Out:
# done

# %%
## testar de vieram certo
#df_cl.head(360)
df_cd.head(400)
# Out:
#      Angle of Attack [deg]  Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 0                   -180.0                 0.006000             6.0000005e-03
# 1                   -179.0                 0.006538             6.5383380e-03
# 2                   -178.0                 0.008151             8.1510246e-03
# 3                   -177.0                 0.010834             1.0833594e-02
# 4                   -176.0                 0.014580             1.4580285e-02
# ..                     ...                      ...                       ...
# 365                  176.0                 0.014634             1.0856134e-02
# 366                  177.0                 0.010856             8.1577105e-03
# 367                  178.0                 0.008158             6.5391767e-03
# 368                  179.0                 0.006539             6.0000038e-03
# 369                  180.0                 0.006000                       END
#
#     Drag Coefficient Cd [-].2 Drag Coefficient Cd [-].3  \
# 0               6.0000019e-03             6.0000019e-03
# 1               6.5383399e-03             6.5383394e-03
# 2               8.1510264e-03             8.1510264e-03
# 3               1.0833595e-02             1.0833595e-02
# 4               1.4580285e-02             1.4580285e-02
# ..                        ...                       ...
# 365                       END             6.5395231e-03
# 366                       END             6.0003665e-03
# 367                       END                       END
# 368                       END                       END
# 369                       END                       END
#
#     Drag Coefficient Cd [-].4 Drag Coefficient Cd [-].5  \
# 0               6.0000019e-03             6.0000042e-03
# 1               6.5383399e-03             6.5383418e-03
# 2               8.1510264e-03             8.1510274e-03
# 3               1.0833595e-02             1.0833596e-02
# 4               1.4580285e-02             1.4580285e-02
# ..                        ...                       ...
# 365             6.0000173e-03             8.1577143e-03
# 366                       END             6.5391823e-03
# 367                       END             6.0000089e-03
# 368                       END                       END
# 369                       END                       END
#
#     Drag Coefficient Cd [-].6 Drag Coefficient Cd [-].7
# 0               6.0000042e-03             6.0000047e-03
# 1               6.5383418e-03             6.5383422e-03
# 2               8.1510283e-03             8.1510283e-03
# 3               1.0833596e-02             1.0833596e-02
# 4               1.4580285e-02             1.4580285e-02
# ..                        ...                       ...
# 365             6.0000052e-03                       END
# 366                       END                       END
# 367                       END                       END
# 368                       END                       END
# 369                       END                       END
#
# [358 rows x 9 columns]

# %% [markdown]
# > uando o numero de rows =360, falta 1
#  de -180 a +180 uma a 1 contando zero, tem 361 elementos

# %%
## remover pontas desnecessárias 

# aoenas 1 vez 

df_cl = df_cl.iloc[90:-89].reset_index(drop=True)
df_cd = df_cd.iloc[90:-89].reset_index(drop=True)

print('done')
# Out:
# done

# %%
# testar se removera certo

df_cd.head(181)
#df_cd.head(181)
# Out:
#      Angle of Attack [deg]  Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 0                    -90.0                 1.696177             1.6961976e+00
# 1                    -89.0                 1.695673             1.6956948e+00
# 2                    -88.0                 1.694164             1.6941867e+00
# 3                    -87.0                 1.691651             1.6916753e+00
# 4                    -86.0                 1.688138             1.6881635e+00
# ..                     ...                      ...                       ...
# 174                   87.0                 1.848197             1.8511090e+00
# 175                   88.0                 1.851070             1.8528329e+00
# 176                   89.0                 1.852795             1.8534081e+00
# 177                   90.0                 1.853372             1.8528340e+00
# 178                   91.0                 1.852800             1.8511113e+00
#
#     Drag Coefficient Cd [-].2 Drag Coefficient Cd [-].3  \
# 107             3.0170032e-01             2.5590134e-01
# 108             3.2583323e-01             2.7858114e-01
# 109             3.5068095e-01             3.0200499e-01
#
#     Drag Coefficient Cd [-].6 Drag Coefficient Cd [-].7
# 80              1.2126772e-02             1.6804358e-02
# 81              1.2114095e-02             1.2766852e-02
# 82              1.2101417e-02             1.2117759e-02
# 83              1.2088740e-02             1.2088740e-02
# 84              1.2076063e-02             1.2076063e-02
# 85              1.2063386e-02             1.2063386e-02
# 86              1.2050709e-02             5.1279999e-02
# 87              1.2025354e-02             5.2700001e-03
# 88              1.2012677e-02             4.2699999e-03
# 89              6.0999999e-03             6.4800000e-03
# 90              5.5499999e-03             9.6300002e-03
# 91              9.2799999e-03             1.0640000e-02
# 92              1.0380000e-02             1.2160000e-02
# 93              1.2830000e-02             1.6060000e-02
# 94              1.4930000e-02             2.3050001e-02
# 95              2.6219999e-02             5.3450000e-02
# 96              4.2810000e-02             1.4927000e-01
# 97              6.4450003e-02             2.3209000e-01
# 98              1.8235999e-01             1.2201907e-01
# 99              1.1988255e-01             1.5909331e-01
# 100             1.5527639e-01             1.9981685e-01
# 101             1.7401275e-01             2.2144525e-01
# 102             1.9350553e-01             2.4387491e-01
# 103             2.1377487e-01             2.6707709e-01
# 104             2.3482718e-01             2.9102451e-01
# 105             2.5665915e-01             3.1569049e-01
# 106             2.7926075e-01             3.4104839e-01
# 107             3.0261686e-01             3.6707124e-01
# 108             3.2670856e-01             3.9373150e-01
# 109             3.5151395e-01             4.2100087e-01

# %%
# pular para rascunho  para teste de interpolaçao

# %% [markdown]
# ## TRATAMENTO PARA MH112

# %%
# implementando outra interpolação CL

# try gpt 
# começa apartir de (Obter linhas que faltam)
# Lê o arquivo CSV em um DataFrame
df = df_cl
#df.iloc[80:91]
#df.head(400)
# Pega as linhas acima e abaixo da linha 88
linha_acima = df.iloc[88]
linha_abaixo = df.iloc[89]


# Inicializa uma nova linha interpolada
linha_interpolada = {}

# Para cada coluna
for coluna in df.columns:
    valor_acima = linha_acima[coluna]
    valor_abaixo = linha_abaixo[coluna]

    # Tenta converter para float e fazer interpolação
    try:
        valor_interp = round((float(valor_acima) + float(valor_abaixo)) / 2, 8)
        #valor_interp = (float(valor_acima) + float(valor_abaixo)) / 2
    except ValueError:
        # Se não for numérico (ex: texto), coloca um valor nulo ou preserva o de cima
        valor_interp = None  # ou use: valor_acima

    linha_interpolada[coluna] = valor_interp

# Converte para DataFrame
linha_interpolada_df = pd.DataFrame([linha_interpolada])

# Insere a nova linha na posição 88
df_novo = pd.concat([df.iloc[:89], linha_interpolada_df, df.iloc[89:]]).reset_index(drop=True)
#df_novo
#df_novo.iloc[80:91]
# Salva o novo arquivo
df_cl = df_novo

# %%
# implementando outra interpolação CD

# try gpt 
# começa apartir de (Obter linhas que faltam)
# Lê o arquivo CSV em um DataFrame
df = df_cd
#df.iloc[80:91]
#df.head(400)
# Pega as linhas acima e abaixo da linha 88
linha_acima = df.iloc[88]
linha_abaixo = df.iloc[89]


# Inicializa uma nova linha interpolada
linha_interpolada = {}

# Para cada coluna
for coluna in df.columns:
    valor_acima = linha_acima[coluna]
    valor_abaixo = linha_abaixo[coluna]

    # Tenta converter para float e fazer interpolação
    try:
        valor_interp = round((float(valor_acima) + float(valor_abaixo)) / 2, 8)
        #valor_interp = (float(valor_acima) + float(valor_abaixo)) / 2
    except ValueError:
        # Se não for numérico (ex: texto), coloca um valor nulo ou preserva o de cima
        valor_interp = None  # ou use: valor_acima

    linha_interpolada[coluna] = valor_interp

# Converte para DataFrame
linha_interpolada_df = pd.DataFrame([linha_interpolada])

# Insere a nova linha na posição 88
df_novo = pd.concat([df.iloc[:89], linha_interpolada_df, df.iloc[89:]]).reset_index(drop=True)

#df_novo
#df_novo.iloc[80:91]
# Salva o novo arquivo
df_cd = df_novo

# %% [markdown]
# ## TRATAMENTO PARA MH116

# %%
## alterações em CL

# alterar incorreto cl 9 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:99]                      # inclui até a linha 98
duplicate_row = df_cl.iloc[[98]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[99:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cl.iloc[99, 0] = 9.0000000e+00

# alterar incorreto cl 10
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:100]                      # inclui até a linha 90
duplicate_row = df_cl.iloc[[100]].copy()   # linha 100 (como DataFrame)
bottom = df_cl.iloc[100:]                  # da linha 100 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cl.iloc[100, 0] = 1.0000000e+01




# show 

df_cl.iloc[95:110]
# Out:
#      Angle of Attack [deg]  Lift Coefficient Cl [-] Lift Coefficient Cl [-].1  \
# 95                     4.0                 0.721700             7.2399998e-01
# 96                     5.0                 0.773400             8.8309997e-01
# 97                     6.0                 0.807300             1.1524000e+00
# 98                     7.0                 0.956900             1.2602000e+00
# 99                     9.0                 0.956900             1.2602000e+00
# 100                   10.0                 1.334200             1.3783000e+00
# 101                    8.0                 1.334200             1.3783000e+00
# 102                   10.0                 1.175200             1.1436000e+00
# 103                   11.0                 1.105800             1.1846000e+00
# 104                   12.0                 1.049400             6.7763084e-01
# 105                   15.0                 1.125500             6.7965174e-01
# 106                   16.0                 0.775512             6.8861121e-01
# 107                   17.0                 0.765632             7.0264208e-01
# 108                   18.0                 0.767207             7.2041261e-01
# 109                   19.0                 0.776513             7.4095237e-01
#
#     Lift Coefficient Cl [-].2 Lift Coefficient Cl [-].3  \
# 95              1.1901000e+00             1.0635000e+00
# 96              1.2966000e+00             1.2457000e+00
# 97              1.3911000e+00             1.2704999e+00
# 98              1.3494999e+00             1.3882999e+00
# 99              1.3494999e+00             1.3882999e+00
# 100             1.1655000e+00             1.3789999e+00
# 101             1.1655000e+00             1.3789999e+00
# 102             1.1917000e+00             1.1774000e+00
# 103             1.0536038e+00             1.1835001e+00
# 104             1.0453581e+00             1.1750274e+00
# 105             1.0415529e+00             1.1611230e+00
# 106             1.0416167e+00             1.1511188e+00
# 107             1.0450125e+00             1.1447500e+00
# 108             1.0512478e+00             1.1417004e+00
# 109             1.0598775e+00             1.1416318e+00
#
#     Lift Coefficient Cl [-].4 Lift Coefficient Cl [-].5  \
# 95              1.1413000e+00             1.2656000e+00
# 96              1.2086999e+00             1.3835000e+00
# 97              1.2785000e+00             1.4550000e+00
# 98              1.3993000e+00             1.4611000e+00
# 99              1.3993000e+00             1.4611000e+00
# 100             1.4342000e+00             1.3898000e+00
# 101             1.4342000e+00             1.3898000e+00
# 102             1.2660000e+00             8.7180245e-01
# 103             8.0744576e-01             8.3500445e-01
# 104             8.2144600e-01             8.4078372e-01
# 105             8.4017795e-01             8.5567671e-01
# 106             8.6241233e-01             8.7662929e-01
# 107             8.8723451e-01             9.0163493e-01
# 108             9.1395313e-01             9.2935276e-01
# 109             9.4203639e-01             9.5886624e-01
#
#     Lift Coefficient Cl [-].6 Lift Coefficient Cl [-].7
# 95              1.2807000e+00             1.4572001e+00
# 96              1.4434000e+00             1.4984000e+00
# 97              1.4944000e+00             1.2535000e+00
# 98              1.4560000e+00             1.2142000e+00
# 99              1.4560000e+00             1.2142000e+00
# 100             1.2244000e+00             1.1776687e+00
# 101             1.2244000e+00             1.1776687e+00
# 102             8.3542109e-01             1.1556790e+00
# 103             8.7030870e-01             1.1582773e+00
# 104             8.9650339e-01             1.1667173e+00
# 105             9.2582381e-01             1.1789296e+00
# 106             9.5713520e-01             1.1942718e+00
# 107             9.8968303e-01             1.2121792e+00
# 108             1.0229473e+00             1.2321579e+00
# 109             1.0565561e+00             1.2537767e+00

# %%
## alterações em CD

# alterar incorreto cd 9 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:99]                      # inclui até a linha 98
duplicate_row = df_cd.iloc[[98]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[99:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[99, 0] = 9.0000000e+00

# alterar incorreto cl 10
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:100]                      # incdui até a linha 90
duplicate_row = df_cd.iloc[[100]].copy()   # linha 100 (como DataFrame)
bottom = df_cd.iloc[100:]                  # da linha 100 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[100, 0] = 1.0000000e+01




# show 

df_cd.iloc[95:110]
# Out:
#      Angle of Attack [deg]  Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 95                     4.0                 0.044240             3.5790000e-02
# 96                     5.0                 0.052240             4.1129999e-02
# 97                     6.0                 0.063720             3.3280000e-02
# 98                     7.0                 0.080330             3.6570001e-02
# 99                     9.0                 0.080330             3.6570001e-02
# 100                   10.0                 0.077630             7.1259998e-02
# 101                    8.0                 0.077630             7.1259998e-02
# 102                   10.0                 0.129320             2.0062999e-01
# 103                   11.0                 0.161470             2.2788000e-01
# 104                   12.0                 0.185330             1.2481813e-01
# 105                   15.0                 0.249760             1.4112215e-01
# 106                   16.0                 0.128915             1.5835574e-01
# 107                   17.0                 0.148534             1.7650372e-01
# 108                   18.0                 0.168507             1.9554880e-01
# 109                   19.0                 0.188959             2.1547197e-01
#
#     Drag Coefficient Cd [-].2 Drag Coefficient Cd [-].3  \
# 95              2.0260001e-02             1.9810000e-02
# 96              3.3890001e-02             1.6340001e-02
# 97              6.3239999e-02             2.7670000e-02
# 98              8.2719997e-02             5.2120000e-02
# 99              8.2719997e-02             5.2120000e-02
# 100             1.8493000e-01             7.3019996e-02
# 101             1.8493000e-01             7.3019996e-02
# 102             2.7625999e-01             1.6071001e-01
# 103             1.6248916e-01             2.8475001e-01
# 104             1.8208589e-01             1.4145707e-01
# 105             2.0257267e-01             1.5990503e-01
# 106             2.2391659e-01             1.7932314e-01
# 107             2.4608693e-01             1.9967085e-01
# 108             2.6905435e-01             2.2091073e-01
# 109             2.9279032e-01             2.4300751e-01
#
#     Drag Coefficient Cd [-].4 Drag Coefficient Cd [-].5  \
# 95              1.0220000e-02             1.6060000e-02
# 96              1.4100000e-02             2.4909999e-02
# 97              2.0210000e-02             3.7570000e-02
# 98              3.5730001e-02             5.6109998e-02
# 99              3.5730001e-02             5.6109998e-02
# 100             5.4740001e-02             7.2530001e-02
# 101             5.4740001e-02             7.2530001e-02
# 102             1.0666000e-01             8.4568866e-02
# 103             1.5451644e-01             1.1813716e-01
# 104             1.7310335e-01             1.3569890e-01
# 105             1.9252191e-01             1.5389837e-01
# 106             2.1276443e-01             1.7279592e-01
# 107             2.3381950e-01             1.9242983e-01
# 108             2.5567251e-01             2.1282127e-01
# 109             2.7830607e-01             2.3397875e-01
#
#     Drag Coefficient Cd [-].6 Drag Coefficient Cd [-].7
# 95              1.4930000e-02             2.3050001e-02
# 96              2.6219999e-02             5.3450000e-02
# 97              4.2810000e-02             1.4927000e-01
# 98              6.4450003e-02             2.3209000e-01
# 99              6.4450003e-02             2.3209000e-01
# 100             1.8235999e-01             1.2201907e-01
# 101             1.8235999e-01             1.2201907e-01
# 102             1.1988255e-01             1.5909331e-01
# 103             1.5527639e-01             1.9981685e-01
# 104             1.7401275e-01             2.2144525e-01
# 105             1.9350553e-01             2.4387491e-01
# 106             2.1377487e-01             2.6707709e-01
# 107             2.3482718e-01             2.9102451e-01
# 108             2.5665915e-01             3.1569049e-01
# 109             2.7926075e-01             3.4104839e-01

# %% [markdown]
# ## TRATAMENTO PARA E63

# %%
# implementando CORRETA interpolação CL

# try gpt 
# começa apartir de (Obter linhas que faltam)
# Lê o arquivo CSV em um DataFrame
df = df_cl
#df.iloc[80:91]
#df.head(400)


### alterar cl 9 

# Pega as linhas acima e abaixo da linha 98
# Pega as linhas acima e abaixo da linha 98
linha_acima = df.iloc[98]
linha_abaixo = df.iloc[99]


# Inicializa uma nova linha interpolada
linha_interpolada = {}

# Para cada coluna
for coluna in df.columns:
    valor_acima = linha_acima[coluna]
    valor_abaixo = linha_abaixo[coluna]

    # Tenta converter para float e fazer interpolação
    try:
        valor_interp = round((float(valor_acima) + float(valor_abaixo)) / 2, 8)
        #valor_interp = (float(valor_acima) + float(valor_abaixo)) / 2
    except ValueError:
        # Se não for numérico (ex: texto), coloca um valor nulo ou preserva o de cima
        valor_interp = None  # ou use: valor_acima

    linha_interpolada[coluna] = valor_interp

# Converte para DataFrame
linha_interpolada_df = pd.DataFrame([linha_interpolada])

# Insere a nova linha na posição 88
df_novo = pd.concat([df.iloc[:99], linha_interpolada_df, df.iloc[99:]]).reset_index(drop=True)
#df_novo
#df_novo.iloc[80:91]
# Salva o novo arquivo
df_cl = df_novo


## alterar  cl 13 
## alterar  cl 14 

# Seleciona as linhas 102 e 103 como base para interpolação
linha_102 = df_cl.iloc[102]
linha_103 = df_cl.iloc[103]
# Valores a serem inseridos na primeira coluna
valores_interpolados = [13, 14]
# Lista para armazenar as novas linhas
novas_linhas = []

# Interpola para os valores 13 e 14
for novo_valor in valores_interpolados:
    nova_linha = {}
    for coluna in df_cl.columns:
        valor_102 = linha_102[coluna]
        valor_103 = linha_103[coluna]

        try:
            # Converte para float e interpola
            valor_102 = float(valor_102)
            valor_103 = float(valor_103)

            x0, x1 = float(linha_102.iloc[0]), float(linha_103.iloc[0])
            y0, y1 = valor_102, valor_103
            x = novo_valor
            # Interpolação linear
            y = y0 + (y1 - y0) * (x - x0) / (x1 - x0)
            nova_linha[coluna] = round(y, 8)
        except ValueError:
            # Se não for numérico, coloca None ou copia valor da linha anterior
            nova_linha[coluna] = None

    # Substitui o valor da primeira coluna pelo valor exato (13 ou 14)
    primeira_coluna = df_cl.columns[0]
    nova_linha[primeira_coluna] = novo_valor

    novas_linhas.append(nova_linha)

# Converte as novas linhas em DataFrame
novas_linhas_df = pd.DataFrame(novas_linhas)

# Insere as novas linhas entre os índices 102 e 103
df_cl = pd.concat([df_cl.iloc[:103], novas_linhas_df, df_cl.iloc[103:]]).reset_index(drop=True)

#print("Linhas 13 e 14 interpoladas entre linhas 102 e 103 inseridas com sucesso.")



print('done')
##
# Out:
# done

# %%
df_cl.iloc[80:110]
# Out:
#      Angle of Attack [deg]  Lift Coefficient Cl [-] Lift Coefficient Cl [-].1  \
# 80                   -10.0                -0.811674            -3.7121862e-01
# 81                    -9.0                -0.693916            -4.1725320e-01
# 82                    -8.0                -0.576159            -5.1235968e-01
# 83                    -7.0                -0.458402            -7.0773089e-01
# 84                    -6.0                -0.340644            -1.1172361e+00
# 85                    -5.0                -0.222887            -1.9478331e+00
# 86                    -4.0                -0.031800            -3.0870000e-01
# 87                    -3.0                -0.108400            -2.5099999e-01
# 88                    -2.0                -0.246300            -2.0829999e-01
# 89                    -1.0                 0.049400            -1.3940001e-01
# 90                     0.0                 0.365900             3.2170001e-01
# 91                     1.0                 0.486300             4.9020001e-01
# 92                     2.0                 0.576000             5.8050001e-01
# 93                     3.0                 0.655000             6.5899998e-01
# 94                     4.0                 0.721700             7.2399998e-01
# 95                     5.0                 0.773400             8.8309997e-01
# 96                     6.0                 0.807300             1.1524000e+00
# 97                     7.0                 0.956900             1.2602000e+00
# 98                     8.0                 1.334200             1.3783000e+00
# 99                     9.0                 1.254700                   1.26095
# 100                   10.0                 1.175200             1.1436000e+00
# 101                   11.0                 1.105800             1.1846000e+00
# 102                   12.0                 1.049400             6.7763084e-01
# 103                   13.0                 1.074767                  0.678304
# 104                   14.0                 1.100133                  0.678978
# 105                   15.0                 1.125500             6.7965174e-01
# 106                   16.0                 0.775512             6.8861121e-01
# 107                   17.0                 0.765632             7.0264208e-01
# 108                   18.0                 0.767207             7.2041261e-01
# 109                   19.0                 0.776513             7.4095237e-01
#
# 85              1.8493950e-01            -1.4559938e-01
# 86              2.9999161e-01             3.6699999e-02
# 87              5.3009582e-01             7.7480000e-01
# 88              6.4514792e-01             8.4090000e-01
# 89              7.6020002e-01             9.6329999e-01
# 90              8.0830002e-01             9.9349999e-01
# 91              9.9119997e-01             1.0957000e+00
# 92              1.0926000e+00             1.1945000e+00
# 93              1.1849000e+00             1.3832999e+00
# 94              1.2807000e+00             1.4572001e+00
# 95              1.4434000e+00             1.4984000e+00
# 96              1.4944000e+00             1.2535000e+00
# 97              1.4560000e+00             1.2142000e+00
# 98              1.2244000e+00             1.1776687e+00
# 99                   1.029911                  1.166674
# 100             8.3542109e-01             1.1556790e+00
# 101             8.7030870e-01             1.1582773e+00
# 102             8.9650339e-01             1.1667173e+00
# 103                  0.906277                  1.170788
# 104                   0.91605                  1.174859
# 105             9.2582381e-01             1.1789296e+00
# 106             9.5713520e-01             1.1942718e+00
# 107             9.8968303e-01             1.2121792e+00
# 108             1.0229473e+00             1.2321579e+00
# 109             1.0565561e+00             1.2537767e+00

# %%
## implementando  CORRETA interpolação Cd

# Começa a partir de "Obter linhas que faltam"
# Lê o DataFrame existente
df = df_cd

### Interpolação entre linhas 98 e 99 (para corrigir ponto intermediário, exemplo cl 9)

# Pega as linhas acima e abaixo da linha 98
linha_acima = df.iloc[98]
linha_abaixo = df.iloc[99]

# Inicializa uma nova linha interpolada
linha_interpolada = {}

# Para cada coluna, faz a interpolação média
for coluna in df.columns:
    valor_acima = linha_acima[coluna]
    valor_abaixo = linha_abaixo[coluna]

    try:
        valor_interp = round((float(valor_acima) + float(valor_abaixo)) / 2, 8)
    except ValueError:
        valor_interp = None  # Ou pode usar: valor_acima

    linha_interpolada[coluna] = valor_interp

# Converte a linha interpolada para DataFrame
linha_interpolada_df = pd.DataFrame([linha_interpolada])

# Insere a nova linha na posição 99
df_novo = pd.concat([df.iloc[:99], linha_interpolada_df, df.iloc[99:]]).reset_index(drop=True)

# Atualiza o DataFrame df_cd
df_cd = df_novo


### Interpolação entre valores 12 e 15 (inserindo 13 e 14), exemplo cl 13 e 14

# Seleciona as linhas de referência
linha_102 = df_cd.iloc[102]
linha_103 = df_cd.iloc[103]

# Valores a serem inseridos na primeira coluna
valores_interpolados = [13, 14]

# Lista para armazenar as novas linhas
novas_linhas = []

# Gera as novas linhas interpoladas
for novo_valor in valores_interpolados:
    nova_linha = {}
    for coluna in df_cd.columns:
        valor_102 = linha_102[coluna]
        valor_103 = linha_103[coluna]

        try:
            valor_102 = float(valor_102)
            valor_103 = float(valor_103)

            x0, x1 = float(linha_102.iloc[0]), float(linha_103.iloc[0])
            y0, y1 = valor_102, valor_103
            x = novo_valor
            y = y0 + (y1 - y0) * (x - x0) / (x1 - x0)
            nova_linha[coluna] = round(y, 8)
        except ValueError:
            nova_linha[coluna] = None

    # Define o valor exato na primeira coluna
    primeira_coluna = df_cd.columns[0]
    nova_linha[primeira_coluna] = novo_valor

    novas_linhas.append(nova_linha)

# Converte para DataFrame
novas_linhas_df = pd.DataFrame(novas_linhas)

pd.set_option('display.max_rows', None)
#pd.set_option('display.max_colwidth', None)

pd.reset_option('display.max_rows')
pd.reset_option('display.max_colwidth')

print(df_cl.iloc[:, [0]])
# Out:
#      Angle of Attack [deg]
# 0                    -90.0
# 1                    -89.0
# 2                    -88.0
# 3                    -87.0
# 4                    -86.0
# ..                     ...
# 177                   87.0
# 178                   88.0
# 179                   89.0
# 180                   90.0
# 181                   91.0
#
# [182 rows x 1 columns]

# %% [markdown]
# ## Save files

# %%
# Save files

df_cl.to_csv('cl.txt', index=False, header=False, sep='\t')
df_cd.to_csv('cd.txt', index=False, header=False, sep='\t')
print('done')
# Out:
# done

# %%
## Save intermediary files
df_cl.to_csv('intermed_cl.txt', index=False, header=False, sep='\t')
df_cd.to_csv('intermed_cd.txt', index=False, header=False, sep='\t')
print('done')

# %% [markdown]
# ## Rascunhos

# %% [markdown]
# uma vez que a maioreia dos exemplos clonando linhas apresenta erro na interpolação, faz-se necessario modificar o método de tratamento das matrizes de cl e cd. sendo que o erro das tratadas aparece da mesma forma , mesmo que os númerod de dgr permanecam em sequencia correta de -90 a +90

# %%
## chat interpol 13 e 14

#import pandas as pd

# Supondo que df_cl já esteja carregado

# Seleciona as linhas 102 e 103 como base para interpolação
linha_102 = df_cl.iloc[102]
linha_103 = df_cl.iloc[103]

# Valores a serem inseridos na primeira coluna
valores_interpolados = [13, 14]

# Lista para armazenar as novas linhas
novas_linhas = []

# Interpola para os valores 13 e 14
for novo_valor in valores_interpolados:
    nova_linha = {}
    for coluna in df_cl.columns:
        valor_102 = linha_102[coluna]
        valor_103 = linha_103[coluna]

        try:
            # Converte para float e interpola
            valor_102 = float(valor_102)
            valor_103 = float(valor_103)

            x0, x1 = float(linha_102.iloc[0]), float(linha_103.iloc[0])
            y0, y1 = valor_102, valor_103
            x = novo_valor
            # Interpolação linear
            y = y0 + (y1 - y0) * (x - x0) / (x1 - x0)
            nova_linha[coluna] = round(y, 8)
        except ValueError:
            # Se não for numérico, coloca None ou copia valor da linha anterior
            nova_linha[coluna] = None

    # Substitui o valor da primeira coluna pelo valor exato (13 ou 14)
    primeira_coluna = df_cl.columns[0]
    nova_linha[primeira_coluna] = novo_valor

    novas_linhas.append(nova_linha)

# Converte as novas linhas em DataFrame
novas_linhas_df = pd.DataFrame(novas_linhas)

# Insere as novas linhas entre os índices 102 e 103
df_cl = pd.concat([df_cl.iloc[:103], novas_linhas_df, df_cl.iloc[103:]]).reset_index(drop=True)

print("Linhas 13 e 14 interpoladas entre linhas 102 e 103 inseridas com sucesso.")

# %%
# try gpt 
# começa apartir de (Obter linhas que faltam)
# Lê o arquivo CSV em um DataFrame
df = df_cd

# %%
# try gpt 
# começa apartir de (Obter linhas que faltam)
# Lê o arquivo CSV em um DataFrame
df = df_cd
#df.iloc[80:91]
#df.head(400)
# Pega as linhas acima e abaixo da linha 88
linha_acima = df.iloc[88]
linha_abaixo = df.iloc[89]


# Inicializa uma nova linha interpolada
linha_interpolada = {}

# Para cada coluna
for coluna in df.columns:
    valor_acima = linha_acima[coluna]
    valor_abaixo = linha_abaixo[coluna]

    # Tenta converter para float e fazer interpolação
    try:
        valor_interp = (float(valor_acima) + float(valor_abaixo)) / 2
    except ValueError:
        # Se não for numérico (ex: texto), coloca um valor nulo ou preserva o de cima
        valor_interp = None  # ou use: valor_acima

    linha_interpolada[coluna] = valor_interp

# Converte para DataFrame
linha_interpolada_df = pd.DataFrame([linha_interpolada])

# Insere a nova linha na posição 88
df_novo = pd.concat([df.iloc[:89], linha_interpolada_df, df.iloc[89:]]).reset_index(drop=True)
#df_novo
#df_novo.iloc[80:91]
# Salva o novo arquivo
df_novo.to_csv('arquivo_mo33dificado.csv', index=False)

print("Linha interpolada inserida com sucesso na linha 89.")

# %%
## alterações em CD ( ANTIGAS A SEREM DESCARTADAS) e63

# alterar incorreto cd 9 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:99]                      # inclui até a linha 98
duplicate_row = df_cd.iloc[[98]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[99:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[99, 0] = 9.0000000e+00

## 
# alterar incorreto cd 13 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:103]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[102]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[103:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[103, 0] = 1.3000000e+01

##

# alterar incorreto cd 14 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:104]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[104]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[104:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[104, 0] = 1.4000000e+01


# show 

df_cd.iloc[95:110]

# %%
## alterações em CL ( ANTIGAS A SEREM DESCARTADAS) e63

# alterar incorreto cl 9 

# add a line between line 98 and 99 that is the same as line 98


# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:99]                      # inclui até a linha 98
duplicate_row = df_cl.iloc[[98]].copy()   # linha 98 (como DataFrame)
bottom = df_cl.iloc[99:]                  # da linha 99 em diante

# Concatenar tudo  ( top + copy + botton) 
      #( linha faltante assume o valor da linha copiada,e entra no seu lugar)
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

# alterar valor do grau 9 
df_cl.iloc[99, 0] = 9.0000000e+00

## 
# alterar incorreto cl 13 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:103]                      # inclui até a linha 97
duplicate_row = df_cl.iloc[[102]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[103:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cl.iloc[103, 0] = 1.3000000e+01

##

# alterar incorreto cl 14 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:104]                      # inclui até a linha 97
duplicate_row = df_cl.iloc[[104]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[104:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cl.iloc[104, 0] = 1.4000000e+01


# show 

df_cl.iloc[95:110]

# %%
# try gpt 



# Pega as linhas acima e abaixo da linha 88
linha_acima = df.iloc[87]
linha_abaixo = df.iloc[88]

# Calcula a média (interpolação linear)
linha_interpolada = (linha_acima + linha_abaixo) / 2

# Insere a nova linha no índice 88
df_parte1 = df.iloc[:88]
df_parte2 = df.iloc[88:]

# Concatena as partes com a nova linha no meio
df_novo = pd.concat([df_parte1, pd.DataFrame([linha_interpolada]), df_parte2], ignore_index=True)

# Salva de volta no CSV (sobrescrevendo)
df_novo.to_csv('arquivo_modificado.csv', index=False)

print("Linha interpolada inserida com sucesso na linha 88.")

# %%
df = df_cl
if len(df) < 89:
    raise ValueError("O arquivo CSV precisa ter pelo menos 89 linhas para inserir na posição 88.")
# Pega as linhas acima e abaixo da linha 88
linha_acima = df.iloc[87]
linha_abaixo = df.iloc[88]
# Calcula a média (interpolação linear)
linha_interpolada = (linha_acima + linha_abaixo) / 2

# %%
## fazer interpolação entre os valores das colunas seguintes 
#da de cima e da de baixo ao inves de coloar a de baixo ou de cima arbitratiamente 

#import pandas as pd

# Caminho do arquivo CSV
#arquivo_csv = 'arquivo_csv'

# Lê o arquivo CSV em um DataFrame
#df = pd.read_csv(arquivo_csv)
df = df_cl
# Verifica se há pelo menos 89 linhas
if len(df) < 89:
    raise ValueError("O arquivo CSV precisa ter pelo menos 89 linhas para inserir na posição 88.")

# Pega as linhas acima e abaixo da linha 88
linha_acima = df.iloc[87]
linha_abaixo = df.iloc[88]

# Calcula a média (interpolação linear)
linha_interpolada = (linha_acima + linha_abaixo) / 2

# Insere a nova linha no índice 88
df_parte1 = df.iloc[:88]
df_parte2 = df.iloc[88:]

# Concatena as partes com a nova linha no meio
df_novo = pd.concat([df_parte1, pd.DataFrame([linha_interpolada]), df_parte2], ignore_index=True)

# Salva de volta no CSV (sobrescrevendo)
df_novo.to_csv('arquivo_modificado.csv', index=False)

print("Linha interpolada inserida com sucesso na linha 88.")

# %%
df_cl.iloc[95:110]

# %%
# alterar incorreto cd 9 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:99]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[98]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[99:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[99, 0] = 9.0000000e+00
# show 

df_cd.iloc[95:105]

# %%
# template codigo de adicionar/ copiar linhas 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:99]                      # inclui até a linha 98
duplicate_row = df_cl.iloc[[98]].copy()   # linha 98 (como DataFrame)
bottom = df_cl.iloc[99:]                  # da linha 99 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cl.iloc[99, 0] = 9.0000000e+00
# show 

df_cl.iloc[95:105]

# %%
import pandas as pd

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df.iloc[:98]                      # inclui até a linha 97
duplicate_row = df.iloc[[97]].copy()   # linha 97 (como DataFrame)
bottom = df.iloc[98:]                  # da linha 98 em diante

# Concatenar tudo
df = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

# %%
df_cl.iloc[99, 0] = 9.0000000e+00

# %%
df_cl.iloc[95:105]

# %%
#corect missing values  cl 9

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:100]                      # inclui até a linha 97
duplicate_row = df_cl.iloc[[99]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[100:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cl.iloc[99, 0] = 9.0000000e+00
#df_cl
print('done')

# %%
# template codigo de adicionar/ copiar linhas 
import pandas as pd

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df.iloc[:98]                      # inclui até a linha 97
duplicate_row = df.iloc[[97]].copy()   # linha 97 (como DataFrame)
bottom = df.iloc[98:]                  # da linha 98 em diante

# Concatenar tudo
df = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

# %%
#corect missing values cl 10

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:100]                      # inclui até a linha 97
duplicate_row = df_cl.iloc[[99]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[100:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cl.iloc[100, 0] = 1.0000000e+01
#df_cl
print('done')

# %%
#corect missing values  cd 8

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:98]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[97]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[98:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cd.iloc[98, 0] = 9.0000000e+00
#df_cld
print('done')

# %%
#corect missing values cd 10

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:100]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[99]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[100:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cd.iloc[100, 0] = 1.0000000e+01
#df_cl
print('done')

# %%
df_cl.iloc[95:110]

# %%
df_cd.iloc[95:110]

# %%
df_cd.head(190)

# %%
df_cl.head(180)

# %%
# Garante que pandas mostre todas as linhas e colunas sem cortar
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
print(df_cl.iloc[:, [0]])

# %%
print(df_cl.iloc[:, [0]])

# %%
print(df_cl.columns)

# %%
df_cl.to_csv('cl.txt', index=False, header=False, sep='\t')
df_cd.to_csv('cd.txt', index=False, header=False, sep='\t')
print('done')

# %%
#df2.to_csv('arquivo_final', index=False, header=False, sep='\t') ( de -180 a +180)
df_cl_1.to_csv('cl_plus.txt', index=False, header=False, sep='\t')
df_cd_1.to_csv('cd_pus.txt', index=False, header=False, sep='\t')

# %%
# paralel test ( coment )

# Example for space- or tab-delimited files
#f = pd.read_csv('data.txt', delimiter='\t')  # or use delimiter=' ' for space

# Save as CSV
#df.to_csv('data.csv', index=False)
#"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl"
#df3.to_csv('C:/Users/pedro/Downloads/Xmobots_Matlab/polares.airfoils/Clark Y/cl/cl.txt', index=False, sep='\t')
df = pd.read_csv('/kaggle/working/cl.txt',delimiter='\t')

print(df.columns)
df.head(12)
#print('/kaggle/working/cl.txt')

# %% [markdown]
# ## Writing to files

# %%
## read and transform, line to line ( coment )


#import csv
#"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl\cl_R_2e4.txt"
# Open the .txt file and read lines
#with open('"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl\cl_R_2e4.txt"', 'r') as txt_file:
#    lines = txt_file.readlines()

# Write to a .csv file
#with open('/kaggle/input/polar-try/cl_R_2e4.txt', 'w', newline='') as csv_file:
#    writer = csv.writer(csv_file)

 #   for line in lines:
 #       row = line.strip().split()  # Change .split() to .split(',') if it's comma-separated
 #       writer.writerow(row)

# %%
df2.to_csv("/kaggle/working/Combined_NOT_Flights_2022.csv", index=False)
#/kaggle/input/polar-try/cl_R_2e4.csv
#print(df2)

# %% [markdown]
# ## Dataframe basics

# %%
pd.set_option("display.max_columns", 500)

# %%
df2.head(3)

# %%
df2.tail(3)

# %%
df2.sample(3, random_state=42)

# %%
df2.sample(frac=0.000001, random_state=42)

# %%
df2.columns

# %%
df.index

# %% [markdown]
# ## Dataframe summary

# %%
df.info()

# %%
df.info(verbose=False)

# %%
df.describe()

# %%
df[["Airline"]].describe()

# %%
df.shape, len(df)

# %% [markdown]
# ## Subsetting Columns

# %%
df[['FlightDate', 'Airline', 'Origin']]

# %%
df[df.columns[:5]]

# %%
df[[c for c in df.columns if 'Time' in c]]

# %% [markdown]
# ## Select dtypes

# %%
df.select_dtypes('int')

# %% [markdown]
# ## Select as series vs dataframe

# %%
df['Airline']

# %%
df[['Airline']]

# %% [markdown]
# ## loc and iloc

# %%
df.iloc[1, 3]

# %%
df.iloc[:5, :5]

# %%
df.iloc[[5]]

# %%
df.iloc[:, 1]

# %%
df.iloc[:, [1, 2]]

# %%
df.loc[:, ['Airline', 'Origin']]

# %% [markdown]
# ## loc filter expressions

# %%
df.loc[df['Airline'] == 'Spirit Air Lines']

# %%
df.loc[(df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-03-30')]

# %%
df.loc[~((df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-03-30'))]

# %% [markdown]
# ## query

# %%
df.query('DepTime > 1130 and (Origin == "DRO")')

# %%
# min_time = 1130
# df.query('DepTime > @min_time and (Origin == "DRO")')  # ValueError: Expression ((DepTime) > (__pd_eval_local_min_time)) & (Series_1_0x200x4c0x3a0x6c0xbf0x7d0x00x0) has forbidden control characters.

min_time = 1130
query_expression = 'DepTime > {} and (Origin == "DRO")'.format(min_time)
df.query(query_expression)

# %% [markdown]
# ## Summary Statistics

# %%
df['DepTime'].min()

# %%
df['DepTime'].max()

# %%
df['DepTime'].mean()

# %%
df['DepTime'].std()

# %%
df['DepTime'].sum()

# %%
df['DepTime'].quantile(0.5)

# %%
df['DepTime'].quantile([0.25, 0.75])

# %% [markdown]
# ## agg

# %%
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(['mean', 'min', 'max'])

# %%
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(
    {
        'DepTime': ['min', 'max'],
        'DepDelay': ['mean'],
        'ArrTime': ['min', 'max']
    }
)

# %% [markdown]
# ## Summarize categoricals

# %%
df['Airline'].unique()

# %%
df['Airline'].nunique()

# %%
df['Airline'].value_counts()

# %%
df[['Airline', 'Origin']].value_counts()

# %%
df[['Airline', 'Origin']].value_counts().reset_index()

# %% [markdown]
# ## rank, shift, cumsum

# %%
df[['CRSDepTime']].rank(method='dense')

# %%
df[['CRSDepTime']].rank(method='first')

# %%
df[['CRSDepTime']].shift(1)

# %%
df[['CRSDepTime']].shift(-1)

# %%
df[['CRSDepTime']].shift(3, fill_value=100)

# %%
df[['CRSDepTime']].cumsum()

# %%
df[['CRSDepTime']].cummax()

# %%
df[['CRSDepTime']].cummin()

# %% [markdown]
# ## Rolling methods

# %%
df[['DepDelayMinutes']].rolling(window=5).mean()

# %% [markdown]
# ## Clip

# %%
df['DepTime'].clip(1000, 2000)

# %% [markdown]
# ## Groupby

# %%
df.groupby('Airline')[['DepDelay']].mean()

# %%
df.groupby('Airline')[['DepDelay']].agg(['mean', 'min', 'max'])

# %%
df_agg = df.groupby('Airline')[['DepDelay', 'ArrDelay']].agg(['mean', 'min', 'max'])

# %%
df_agg.columns

# %%
df_agg.columns.to_flat_index()

# %%
df_agg.columns = ["_".join(c) for c in df_agg.columns]

# %%
df_agg

# %% [markdown]
# ## New columns

# %%
df['DepTime2'] = df['DepTime'] / 60

# %%
df.head(3)
# Out:
#    Angle of Attack [deg]  Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 0                  -90.0                 1.696177             1.6961976e+00
# 1                  -89.0                 1.695673             1.6956948e+00
# 2                  -88.0                 1.694164             1.6941867e+00
#
#   Drag Coefficient Cd [-].2 Drag Coefficient Cd [-].3  \
# 0             1.6961915e+00             1.6961920e+00
# 1             1.6956882e+00             1.6956888e+00
# 2             1.6941799e+00             1.6941805e+00
#
#   Drag Coefficient Cd [-].4 Drag Coefficient Cd [-].5  \
# 0             1.6961907e+00             1.6961782e+00
# 1             1.6956874e+00             1.6956742e+00
# 2             1.6941791e+00             1.6941650e+00
#
#   Drag Coefficient Cd [-].6 Drag Coefficient Cd [-].7
# 0             1.6961751e+00             1.6961811e+00
# 1             1.6956708e+00             1.6956773e+00
# 2             1.6941613e+00             1.6941684e+00

# %%
df = df.assign(DepTime3 = df['DepTime'] / 60)
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DepTime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 df = df.assign(DepTime3 = df['DepTime'] / 60)
#       2 df.head(3)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'DepTime'

# %% [markdown]
# ## Sorting

# %%
df.sort_values('ArrDelay')

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay', ascending=False)

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay', ascending=False).reset_index(drop=True)

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_index()

# %% [markdown]
# ## Missing data

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].isna()

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].isna().sum()

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].dropna(subset=['ArrDelay'])

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].fillna(-999)

# %%
df['ArrDelay'].fillna(df['ArrDelay'].mean())

# %% [markdown]
# ## Concat

# %%
df1 = df.query('Airline == "Southwest Airlines Co."').copy()
df2 = df.query('Airline == "Delta Air Lines Inc."').copy()

# %%
pd.concat([df1, df2])

# %%
df_stack = pd.concat([df1, df2])

# %%
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# %%
df_side = pd.concat([df1, df2], axis=1)

# %%
df1.shape, df2.shape, df_stack.shape, df_side.shape

# %% [markdown]
# ## Merge dataframes

# %%
df1 = df.groupby(['Airline', 'FlightDate'])[['DepDelay']].mean().reset_index()
df2 = df.groupby(['Airline', 'FlightDate'])[['ArrDelay']].mean().reset_index()

# %%
df2

# %%
df1.merge(df2, how="left")

# %%
df1.merge(df2, how="right")

# %%
df1.merge(df2, how="outer")

# %% [markdown]
# ## Merge suffixes

# %%
pd.merge(df1, df2, on=['Airline', 'FlightDate'])

# %%
pd.merge(df1, df2, on=['Airline'])

# %%
pd.merge(df1, df2, on=['Airline'], suffixes=('_dep', '_arr'))

# %%
pd.merge(df1, df2, left_on=['Airline'], right_on=['Airline'])
