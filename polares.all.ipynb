# %% [markdown]
# ##Use coeficientes CL e Cd From Qblade

# %%
import pandas as pd
import sys
import csv

print(sys.version)
print('pandas version', pd.__version__)
# Out:
# 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:40:32) [GCC 12.3.0]
# pandas version 2.0.3

# %%
#/kaggle/input/polar-try/Clark Y

# %% [markdown]
# ## Reading from files ( No edit from Qblade )

# %%
df_cd = pd.read_csv("/kaggle/input/polar-try/Clark Y/esconde_geim/all_cd.txt",delimiter='\t',skiprows=2)
df_cl = pd.read_csv("/kaggle/input/polar-try/Clark Y/esconde_geim/all_cl.txt",delimiter='\t',skiprows=2)
#/kaggle/input/polar-try/Clark Y/esconde_geim/all_cd.txt
#df2 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_4.5e4.txt",delimiter='\t', skiprows=1, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
df3 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_1e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
df4 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cd/cd_R_4.5e4.txt",delimiter='\t', skiprows=1)
#df_temp = pd.read_csv('arquivo.csv', nrows=0)
#print(df2.columns)
#df2.head(12)
#df2['cl_next'] = df3.iloc[:, 1]

#print(df.columns)
df_cl.head(6)
#df_cd.head(12)

#print(df2.columns)
#df2.head(12)
#/kaggle/input/polar-try/E63
# Out:
#   Angle of Attack [deg] Lift Coefficient Cl [-] Angle of Attack [deg].1  \
# 0        -1.8000000e+02           2.9689870e-03          -1.8000000e+02
# 1        -1.7900000e+02           8.5627779e-02          -1.7900000e+02
# 2        -1.7800000e+02           1.6824813e-01          -1.7800000e+02
# 3        -1.7700000e+02           2.4998328e-01          -1.7700000e+02
# 4        -1.7600000e+02           3.2716894e-01          -1.7600000e+02
# 5        -1.7500000e+02           3.9226991e-01          -1.7500000e+02
#
#   Lift Coefficient Cl [-].1  Angle of Attack [deg].2  \
# 0             1.6648071e-03                   -180.0
# 1             1.6343589e-01                   -179.0
# 2             3.2518750e-01                   -178.0
# 3             4.8475948e-01                   -177.0
# 4             6.2700444e-01                   -176.0
# 5             7.1756905e-01                   -175.0
#
#    Lift Coefficient Cl [-].2  Angle of Attack [deg].3  \
# 0                  -0.042531                   -180.0
# 1                   0.114674                   -179.0
# 2                   0.271375                   -178.0
# 3                   0.420565                   -177.0
# 4                   0.538810                   -176.0
# 5                   0.594344                   -175.0
#
#    Lift Coefficient Cl [-].3  Angle of Attack [deg].4  \
# 0                  -0.070439                   -180.0
# 1                   0.059450                   -179.0
# 2                   0.187801                   -178.0
# 3                   0.305953                   -177.0
# 4                   0.394915                   -176.0
# 5                   0.436766                   -175.0
#
#    Lift Coefficient Cl [-].4  Angle of Attack [deg].5  \
# 0                  -0.109438                   -180.0
# 1                  -0.015513                   -179.0
# 2                   0.069195                   -178.0
# 3                   0.136155                   -177.0
# 4                   0.180689                   -176.0
# 5                   0.205765                   -175.0
#
#    Lift Coefficient Cl [-].5  Angle of Attack [deg].6  \
# 0                  -0.109492                   -180.0
# 1                  -0.061858                   -179.0
# 6                    0.024676                   -174.0
# 7                    0.031374                   -173.0
# 8                    0.039074                   -172.0
# 9                    0.047766                   -171.0
# 10                   0.057437                   -170.0
# 11                   0.068075                   -169.0
#
#     Drag Coefficient Cd [-].4  Angle of Attack [deg].5  \
# 0                    0.006000                   -180.0
# 1                    0.006522                   -179.0
# 2                    0.008086                   -178.0
# 3                    0.010689                   -177.0
# 4                    0.014326                   -176.0
# 5                    0.018991                   -175.0
# 6                    0.024676                   -174.0
# 7                    0.031374                   -173.0
# 8                    0.039074                   -172.0
# 9                    0.047766                   -171.0
# 10                   0.057437                   -170.0
# 11                   0.068075                   -169.0
#
#     Drag Coefficient Cd [-].5  Angle of Attack [deg].6  \
# 0                    0.006000                   -180.0
# 1                    0.006522                   -179.0
# 2                    0.008086                   -178.0
# 3                    0.010689                   -177.0
# 4                    0.014326                   -176.0
# 5                    0.018991                   -175.0
# 6                    0.024676                   -174.0
# 7                    0.031374                   -173.0
# 8                    0.039074                   -172.0
# 9                    0.047766                   -171.0
# 10                   0.057437                   -170.0
# 11                   0.068075                   -169.0
#
#     Drag Coefficient Cd [-].6  Angle of Attack [deg].7  \
# 0                    0.006000                   -180.0
# 1                    0.006522                   -179.0
# 2                    0.008086                   -178.0
# 3                    0.010689                   -177.0
# 4                    0.014326                   -176.0
# 5                    0.018991                   -175.0
# 6                    0.024676                   -174.0
# 7                    0.031374                   -173.0
# 8                    0.039074                   -172.0
# 9                    0.047766                   -171.0
# 10                   0.057437                   -170.0
# 11                   0.068075                   -169.0
#
#     Drag Coefficient Cd [-].7 Angle of Attack [deg].8  \
# 0                    0.006000          -4.0000000e+00
# 1                    0.006522          -3.0000000e+00
# 2                    0.008086          -2.0000000e+00
# 3                    0.010689          -1.0000000e+00
# 4                    0.014326           0.0000000e+00
# 5                    0.018991           1.0000000e+00
# 6                    0.024676           2.0000000e+00
# 7                    0.031374           3.0000000e+00
# 8                    0.039074           4.0000000e+00
# 9                    0.047766           5.0000000e+00
# 10                   0.057437           6.0000000e+00
# 11                   0.068075           7.0000000e+00
#
#    Drag Coefficient Cd [-].8
# 0              8.8499999e-03
# 1              8.2799997e-03
# 2              7.8800004e-03
# 3              7.2699999e-03
# 4              6.6300002e-03
# 5              5.5200001e-03
# 6              5.8400002e-03
# 7              6.4699999e-03
# 8              7.5800000e-03
# 9              8.3400002e-03
# 10             9.0500005e-03
# 11             9.9499999e-03

# %%
df_cl.head(12)
# Out:
#    Angle of Attack [deg] Lift Coefficient Cl [-] Angle of Attack [deg].1  \
# 0         -1.8000000e+02           2.9689870e-03          -1.8000000e+02
# 1         -1.7900000e+02           8.5627779e-02          -1.7900000e+02
# 2         -1.7800000e+02           1.6824813e-01          -1.7800000e+02
# 3         -1.7700000e+02           2.4998328e-01          -1.7700000e+02
# 4         -1.7600000e+02           3.2716894e-01          -1.7600000e+02
# 5         -1.7500000e+02           3.9226991e-01          -1.7500000e+02
# 6         -1.7400000e+02           4.3673518e-01          -1.7400000e+02
# 6                    0.145388                   -174.0
# 7                    0.168284                   -173.0
# 8                    0.190390                   -172.0
# 9                    0.212095                   -171.0
# 10                   0.233538                   -170.0
# 11                   0.254725                   -169.0
#
#     Lift Coefficient Cl [-].7 Angle of Attack [deg].8  \
# 0                   -0.107245          -4.0000000e+00
# 1                   -0.016287          -3.0000000e+00
# 2                    0.072315          -2.0000000e+00
# 3                    0.152360          -1.0000000e+00
# 4                    0.214537           0.0000000e+00
# 5                    0.252585           1.0000000e+00
# 6                    0.269131           2.0000000e+00
# 7                    0.273360           3.0000000e+00
# 8                    0.274124           4.0000000e+00
# 9                    0.276462           5.0000000e+00
# 10                   0.282111           6.0000000e+00
# 11                   0.291071           7.0000000e+00
#
#    Lift Coefficient Cl [-].8
# 0             -4.4599999e-02
# 1              6.5399997e-02
# 2              1.7560001e-01
# 3              2.8500000e-01
# 4              3.9260000e-01
# 5              4.9020001e-01
# 6              6.3760000e-01
# 7              7.4250001e-01
# 8              8.3240002e-01
# 9              9.3159997e-01
# 10             1.0332000e+00
# 11             1.1327000e+00

# %%
columns_to_drop_cd = [
    'Angle of Attack [deg].1',
    'Angle of Attack [deg].2',
    'Angle of Attack [deg].3',
    'Angle of Attack [deg].4',
    'Angle of Attack [deg].5',
    'Angle of Attack [deg].6',
    'Angle of Attack [deg].7',
    'Angle of Attack [deg].8',
    'Drag Coefficient Cd [-].8'
]
#Drag Coefficient Cd [-].8
columns_to_drop_cl = [
    'Angle of Attack [deg].1',
    'Angle of Attack [deg].2',
    'Angle of Attack [deg].3',
    'Angle of Attack [deg].4',
    'Angle of Attack [deg].5',
    'Angle of Attack [deg].6',
    'Angle of Attack [deg].7',
    'Angle of Attack [deg].8',
    'Lift Coefficient Cl [-].8'
]

df_cl = df_cl.drop(columns=columns_to_drop_cl, errors='ignore')
df_cd = df_cd.drop(columns=columns_to_drop_cd, errors='ignore')

# %%
df_cd.head(6)
# Out:
#   Angle of Attack [deg] Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 0        -1.8000000e+02           6.0000275e-03             6.0000126e-03
# 1        -1.7900000e+02           6.5219859e-03             6.5219710e-03
# 2        -1.7800000e+02           8.0861589e-03             8.0861449e-03
# 3        -1.7700000e+02           1.0689046e-02             1.0689033e-02
# 4        -1.7600000e+02           1.4325886e-02             1.4325875e-02
# 5        -1.7500000e+02           1.8990668e-02             1.8990660e-02
#
#    Drag Coefficient Cd [-].2  Drag Coefficient Cd [-].3  \
# 0                   0.006000                   0.006000
# 1                   0.006522                   0.006522
# 2                   0.008086                   0.008086
# 3                   0.010689                   0.010689
# 4                   0.014326                   0.014326
# 5                   0.018991                   0.018991
#
#    Drag Coefficient Cd [-].4  Drag Coefficient Cd [-].5  \
# 0                   0.006000                   0.006000
# 1                   0.006522                   0.006522
# 2                   0.008086                   0.008086
# 3                   0.010689                   0.010689
# 4                   0.014326                   0.014326
# 5                   0.018991                   0.018991
#
#    Drag Coefficient Cd [-].6  Drag Coefficient Cd [-].7
# 0                   0.006000                   0.006000
# 1                   0.006522                   0.006522
# 2                   0.008086                   0.008086
# 3                   0.010689                   0.010689
# 4                   0.014326                   0.014326
# 5                   0.018991                   0.018991

# %%
df_cl.head(6)
# Out:
#   Angle of Attack [deg] Lift Coefficient Cl [-] Lift Coefficient Cl [-].1  \
# 0        -1.8000000e+02           2.9689870e-03             1.6648071e-03
# 1        -1.7900000e+02           8.5627779e-02             1.6343589e-01
# 2        -1.7800000e+02           1.6824813e-01             3.2518750e-01
# 3        -1.7700000e+02           2.4998328e-01             4.8475948e-01
# 4        -1.7600000e+02           3.2716894e-01             6.2700444e-01
# 5        -1.7500000e+02           3.9226991e-01             7.1756905e-01
#
#    Lift Coefficient Cl [-].2  Lift Coefficient Cl [-].3  \
# 0                  -0.042531                  -0.070439
# 1                   0.114674                   0.059450
# 2                   0.271375                   0.187801
# 3                   0.420565                   0.305953
# 4                   0.538810                   0.394915
# 5                   0.594344                   0.436766
#
#    Lift Coefficient Cl [-].4  Lift Coefficient Cl [-].5  \
# 0                  -0.109438                  -0.109492
# 1                  -0.015513                  -0.061858
# 2                   0.069195                  -0.020553
# 3                   0.136155                   0.016212
# 4                   0.180689                   0.049745
# 5                   0.205765                   0.080956
#
#    Lift Coefficient Cl [-].6  Lift Coefficient Cl [-].7
# 0                  -0.108166                  -0.107245
# 1                  -0.038060                  -0.016287
# 2                   0.017259                   0.072315
# 3                   0.059796                   0.152360
# 4                   0.093177                   0.214537
# 5                   0.120869                   0.252585

# %%
# aoenas 1 vez
df_cl = df_cl.iloc[90:-91].reset_index(drop=True)
df_cd = df_cd.iloc[90:-91].reset_index(drop=True)
print('done')
# Out:
# done

# %%
df_cl.head(180)
# Out:
#     Angle of Attack [deg] Lift Coefficient Cl [-] Lift Coefficient Cl [-].1  \
# 0          -9.0000000e+01          -1.3491565e-01            -1.3474798e-01
# 1          -8.9000000e+01          -1.6374753e-01            -1.6357233e-01
# 2          -8.8000000e+01          -1.9234265e-01            -1.9215980e-01
# 3          -8.7000000e+01          -2.2066791e-01            -2.2047730e-01
# 4          -8.6000000e+01          -2.4869077e-01            -2.4849224e-01
# ..                    ...                     ...                       ...
# 175         8.7000000e+01           8.9815435e+00             7.9366498e-02
# 176         8.8000000e+01           9.0848675e+00             4.8812229e-02
# 177         8.9000000e+01           9.1881905e+00             1.8156223e-02
# 178         9.0000000e+01           9.2915144e+00            -1.2563342e-02
# 179         9.1000000e+01           9.3948374e+00            -4.3307923e-02
#
#      Lift Coefficient Cl [-].2  Lift Coefficient Cl [-].3  \
# 0                    -0.083028                  -0.065486
# 1                    -0.101244                  -0.080078
# 2                    -0.119332                  -0.094581
# 3                    -0.137282                  -0.108991
# 4                    -0.155080                  -0.123301
# ..                         ...                        ...
# 175                   0.398242                   0.457013
# 176                   0.359175                   0.414297
# 177                   0.319590                   0.371042
# 178                   0.279540                   0.327305
# 179                   0.239080                   0.283144
#
#      Lift Coefficient Cl [-].4  Lift Coefficient Cl [-].5  \
# 0                    -0.049932                  -0.061844
# 1                    -0.061297                  -0.075924
# 2                    -0.072607                  -0.089919
# 3                    -0.083864                  -0.103825
# 4                    -0.095069                  -0.117638
# ..                         ...                        ...
# 175                   0.485675                   0.449885
# 176                   0.440767                   0.407630
# 177                   0.395294                   0.364842
# 178                   0.349315                   0.321577
# 179                   0.302891                   0.277892
#
#      Lift Coefficient Cl [-].6  Lift Coefficient Cl [-].7
# 0                    -0.059980                  -0.059472
# 1                    -0.073625                  -0.072994
# 2                    -0.087190                  -0.086438
# 3                    -0.100671                  -0.099800
# 4                    -0.114067                  -0.113077
# ..                         ...                        ...
# 175                   0.464513                   0.466228
# 176                   0.421565                   0.423136
# 177                   0.378087                   0.379513
# 178                   0.334136                   0.335415
# 179                   0.289768                   0.290899
#
# [180 rows x 9 columns]

# %%
df_cd.head(180)
# Out:
#     Angle of Attack [deg] Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 0          -9.0000000e+01           1.6703783e+00             1.6703992e+00
# 1          -8.9000000e+01           1.6698773e+00             1.6698992e+00
# 2          -8.8000000e+01           1.6683780e+00             1.6684011e+00
# 3          -8.7000000e+01           1.6658825e+00             1.6659067e+00
# 4          -8.6000000e+01           1.6623933e+00             1.6624187e+00
# ..                    ...                     ...                       ...
# 175         8.7000000e+01           2.0280620e-02             1.7684733e+00
# 176         8.8000000e+01           2.0375799e-02             1.7657514e+00
# 177         8.9000000e+01           2.0470979e-02             1.7619455e+00
# 178         9.0000000e+01           2.0566158e-02             1.7570602e+00
# 179         9.1000000e+01           2.0661337e-02             1.7511017e+00
#
#      Drag Coefficient Cd [-].2  Drag Coefficient Cd [-].3  \
# 0                     1.670398                   1.670394
# 1                     1.669898                   1.669894
# 2                     1.668400                   1.668395
# 3                     1.665906                   1.665901
# 4                     1.662418                   1.662413
# ..                         ...                        ...
# 175                   1.756636                   1.753410
# 176                   1.761540                   1.758438
# 177                   1.765365                   1.762382
# 178                   1.768104                   1.765237
# 179                   1.769755                   1.767000
#
#      Drag Coefficient Cd [-].4  Drag Coefficient Cd [-].5  \
# 0                     1.670384                   1.670383
# 1                     1.669884                   1.669882
# 2                     1.668385                   1.668384
# 3                     1.665889                   1.665888
# 4                     1.662400                   1.662399
# ..                         ...                        ...
# 175                   1.751996                   1.753689
# 176                   1.757083                   1.758715
# 177                   1.761083                   1.762656
# 178                   1.763992                   1.765508
# 179                   1.765807                   1.767268
#
#      Drag Coefficient Cd [-].6  Drag Coefficient Cd [-].7
# 0                     1.670383                   1.670382
# 1                     1.669882                   1.669881
# 2                     1.668383                   1.668382
# 3                     1.665887                   1.665887
# 4                     1.662398                   1.662398
# ..                         ...                        ...
# 175                   1.751748                   1.751625
# 176                   1.756851                   1.756735
# 177                   1.760867                   1.760756
# 178                   1.763792                   1.763686
# 179                   1.765621                   1.765520
#
# [180 rows x 9 columns]

# %%
# 90                    0.389900                   0.392600
# 91                    0.492400                   0.490200
# 92                    0.644500                   0.637600
# 93                    0.740900                   0.742500
# 94                    0.830700                   0.832400
# 95                    0.926900                   0.931600
# 96                    1.026900                   1.033200
# 97                    1.125900                   1.132700
# 98                    1.215600                   1.217000
# 99                    1.290600                   1.299400
# 100                   1.354900                   1.355000
# 101                   1.399100                   1.415200
# 102                   1.439100                   1.467700
# 103                   1.472600                   1.497000
# 104                   1.486100                   1.507200
# 105                   1.462900                   1.518400
# 106                   1.408700                   1.507700
# 107                   1.385900                   1.476100
# 108                   1.353800                   1.429400
# 109                   1.320800                   1.378900
# 110                   1.291100                   1.338000
# 111                   1.426286                   1.449477
# 112                   1.410489                   1.432654
# 113                   1.395754                   1.416775
# 114                   1.382482                   1.402299
# 115                   1.370908                   1.389507
# 116                   1.361136                   1.378537
# 117                   1.353171                   1.369417
# 118                   1.346946                   1.362099
# 119                   1.342345                   1.356473
# 120                   1.339217                   1.352397

# %%
#corect missing values  cl 8

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:98]                      # inclui até a linha 97
duplicate_row = df_cl.iloc[[97]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[98:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cl.iloc[98, 0] = 8.0000000e+00
#df_cl
print('done')

#corect missing values cl 10

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:100]                      # inclui até a linha 97
duplicate_row = df_cl.iloc[[99]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[100:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cl.iloc[100, 0] = 1.0000000e+01
#df_cl
print('done')
# Out:
# done
# done
# done
# done

# %%
#corect missing values  cd 8

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:98]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[97]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[98:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cd.iloc[98, 0] = 8.0000000e+00
#df_cld
print('done')

#corect missing values cd 10

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:100]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[99]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[100:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cd.iloc[100, 0] = 1.0000000e+01
#df_cl
print('done')
# Out:
# done
# done
# done
# done

# %%
df_cl.iloc[95:110]
# 98                    8.0           8.0969997e-02             6.2080000e-02
# 99          9.0000000e+00           1.0234000e-01             7.0510000e-02
# 100                  10.0           1.0234000e-01             7.0510000e-02
# 101         1.1000000e+01           1.3700999e-01             5.0730001e-02
# 102         1.2000000e+01           1.5670000e-01             5.1970001e-02
# 103         1.3000000e+01           1.3979000e-01             2.3514000e-01
# 104         1.4000000e+01           1.4926000e-01             2.4933000e-01
# 105         1.5000000e+01           1.9653000e-01             2.6075000e-01
# 106         1.6000000e+01           2.1020000e-01             2.2762617e-01
# 107         1.7000000e+01           2.2594000e-01             2.4848679e-01
# 108         1.8000000e+01           2.4135000e-01             2.7010173e-01
# 109         1.9000000e+01           2.5847000e-01             2.9245141e-01
#
#      Drag Coefficient Cd [-].2  Drag Coefficient Cd [-].3  \
# 95                     0.02277                    0.01801
# 96                     0.02404                    0.01944
# 97                     0.02540                    0.02096
# 98                     0.02540                    0.02096
# 99                     0.02731                    0.02296
# 100                    0.02731                    0.02296
# 101                    0.02955                    0.02530
# 102                    0.03297                    0.02773
# 103                    0.03636                    0.03136
# 104                    0.04087                    0.03673
# 105                    0.04810                    0.04479
# 106                    0.06186                    0.05934
# 107                    0.07888                    0.07401
# 108                    0.10093                    0.08906
# 109                    0.17177                    0.10678
#
#      Drag Coefficient Cd [-].4  Drag Coefficient Cd [-].5  \
# 95                     0.01170                    0.00975
# 96                     0.01308                    0.01078
# 97                     0.01450                    0.01181
# 98                     0.01450                    0.01181
# 99                     0.01600                    0.01298
# 100                    0.01600                    0.01298
# 101                    0.01749                    0.01545
# 102                    0.02042                    0.01801
# 103                    0.02433                    0.02229
# 104                    0.02936                    0.02684
# 105                    0.03830                    0.03403
# 106                    0.05006                    0.04630
# 107                    0.06646                    0.05986
# 108                    0.08250                    0.07564
# 109                    0.09886                    0.09419
#
#      Drag Coefficient Cd [-].6  Drag Coefficient Cd [-].7
# 95                     0.00890                    0.00834
# 96                     0.00973                    0.00905
# 97                     0.01063                    0.00995
# 98                     0.01063                    0.00995
# 99                     0.01217                    0.01195
# 100                    0.01217                    0.01195
# 101                    0.01460                    0.01390
# 102                    0.01715                    0.01708
# 103                    0.02082                    0.01968
# 104                    0.02515                    0.02294
# 105                    0.03053                    0.02833
# 106                    0.03853                    0.03634
# 107                    0.05188                    0.04544
# 108                    0.07164                    0.05846
# 109                    0.08916                    0.07601

# %%
df_cd.head(190)
# Out:
#     Angle of Attack [deg] Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 0          -9.0000000e+01           1.6703783e+00             1.6703992e+00
# 1          -8.9000000e+01           1.6698773e+00             1.6698992e+00
# 2          -8.8000000e+01           1.6683780e+00             1.6684011e+00
# 3          -8.7000000e+01           1.6658825e+00             1.6659067e+00
# 4          -8.6000000e+01           1.6623933e+00             1.6624187e+00
# ..                    ...                     ...                       ...
# 177         8.7000000e+01           2.0280620e-02             1.7684733e+00
# 178         8.8000000e+01           2.0375799e-02             1.7657514e+00
# 179         8.9000000e+01           2.0470979e-02             1.7619455e+00
# 180         9.0000000e+01           2.0566158e-02             1.7570602e+00
# 181         9.1000000e+01           2.0661337e-02             1.7511017e+00
#
#      Drag Coefficient Cd [-].2  Drag Coefficient Cd [-].3  \
# 0                     1.670398                   1.670394
# 1                     1.669898                   1.669894
# 2                     1.668400                   1.668395
# 3                     1.665906                   1.665901
# 4                     1.662418                   1.662413
# ..                         ...                        ...
# 177                   1.756636                   1.753410
# 178                   1.761540                   1.758438
# 179                   1.765365                   1.762382
# 180                   1.768104                   1.765237
# 181                   1.769755                   1.767000
#
#      Drag Coefficient Cd [-].4  Drag Coefficient Cd [-].5  \
# 0                     1.670384                   1.670383
# 1                     1.669884                   1.669882
# 2                     1.668385                   1.668384
# 3                     1.665889                   1.665888
# 4                     1.662400                   1.662399
# ..                         ...                        ...
# 177                   1.751996                   1.753689
# 178                   1.757083                   1.758715
# 179                   1.761083                   1.762656
# 180                   1.763992                   1.765508
# 181                   1.765807                   1.767268
#
#      Drag Coefficient Cd [-].6  Drag Coefficient Cd [-].7
# 0                     1.670383                   1.670382
# 1                     1.669882                   1.669881
# 2                     1.668383                   1.668382
# 3                     1.665887                   1.665887
# 4                     1.662398                   1.662398
# ..                         ...                        ...
# 177                   1.751748                   1.751625
# 178                   1.756851                   1.756735
# 179                   1.760867                   1.760756
# 180                   1.763792                   1.763686
# 181                   1.765621                   1.765520
#
# [182 rows x 9 columns]

# %%
df_cl.head(180)
# Out:
#     Angle of Attack [deg] Lift Coefficient Cl [-] Lift Coefficient Cl [-].1  \
# 0          -9.0000000e+01          -1.3491565e-01            -1.3474798e-01
# 1          -8.9000000e+01          -1.6374753e-01            -1.6357233e-01
# 2          -8.8000000e+01          -1.9234265e-01            -1.9215980e-01
# 3          -8.7000000e+01          -2.2066791e-01            -2.2047730e-01
# 4          -8.6000000e+01          -2.4869077e-01            -2.4849224e-01
# ..                    ...                     ...                       ...
# 175         8.5000000e+01           8.7748966e+00             1.4001912e-01
# 176         8.6000000e+01           8.8782206e+00             1.0978124e-01
# 177         8.7000000e+01           8.9815435e+00             7.9366498e-02
# 178         8.8000000e+01           9.0848675e+00             4.8812229e-02
# 179         8.9000000e+01           9.1881905e+00             1.8156223e-02
#
#      Lift Coefficient Cl [-].2  Lift Coefficient Cl [-].3  \
# 0                    -0.083028                  -0.065486
# 1                    -0.101244                  -0.080078
# 2                    -0.119332                  -0.094581
# 3                    -0.137282                  -0.108991
# 4                    -0.155080                  -0.123301
# ..                         ...                        ...
# 175                   0.474612                   0.540603
# 176                   0.436738                   0.499133
# 177                   0.398242                   0.457013
# 178                   0.359175                   0.414297
# 179                   0.319590                   0.371042
#
#      Lift Coefficient Cl [-].4  Lift Coefficient Cl [-].5  \
# 0                    -0.049932                  -0.061844
# 1                    -0.061297                  -0.075924
# 2                    -0.072607                  -0.089919
# 3                    -0.083864                  -0.103825
# 4                    -0.095069                  -0.117638
# ..                         ...                        ...
# 175                   0.573565                   0.532586
# 176                   0.529960                   0.491555
# 177                   0.485675                   0.449885
# 178                   0.440767                   0.407630
# 179                   0.395294                   0.364842
#
#      Lift Coefficient Cl [-].6  Lift Coefficient Cl [-].7
# 0                    -0.059980                  -0.059472
# 1                    -0.073625                  -0.072994
# 2                    -0.087190                  -0.086438
# 3                    -0.100671                  -0.099800
# 4                    -0.114067                  -0.113077
# ..                         ...                        ...
# 175                   0.548606                   0.550604
# 176                   0.506878                   0.508735
# 177                   0.464513                   0.466228
# 178                   0.421565                   0.423136
# 179                   0.378087                   0.379513
#
# [180 rows x 9 columns]

# %%
# Garante que pandas mostre todas as linhas e colunas sem cortar
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
print(df_cl.iloc[:, [0]])
# Out:
#     Angle of Attack [deg]
# 0          -9.0000000e+01
# 1          -8.9000000e+01
# 2          -8.8000000e+01
# 3          -8.7000000e+01
# 4          -8.6000000e+01
# 5          -8.5000000e+01
# 6          -8.4000000e+01
# 7          -8.3000000e+01
# 8          -8.2000000e+01
# 9          -8.1000000e+01
# 10         -8.0000000e+01
# 11         -7.9000000e+01
# 12         -7.8000000e+01
# 13         -7.7000000e+01
# 14         -7.6000000e+01
# 15         -7.5000000e+01
# 16         -7.4000000e+01
# 17         -7.3000000e+01
# 18         -7.2000000e+01
# 19         -7.1000000e+01
# 20         -7.0000000e+01
# 21         -6.9000000e+01
# 22         -6.8000000e+01
# 23         -6.7000000e+01
# 24         -6.6000000e+01
# 25         -6.5000000e+01
# 26         -6.4000000e+01
# 27         -6.3000000e+01
# 28         -6.2000000e+01
# 29         -6.1000000e+01
# 30         -6.0000000e+01
# 31         -5.9000000e+01
# 32         -5.8000000e+01
# 33         -5.7000000e+01
# 34         -5.6000000e+01
# 35         -5.5000000e+01
# 36         -5.4000000e+01
# 37         -5.3000000e+01
# 38         -5.2000000e+01
# 39         -5.1000000e+01
# 40         -5.0000000e+01
# 41         -4.9000000e+01
# 42         -4.8000000e+01
# 43         -4.7000000e+01
# 44         -4.6000000e+01
# 45         -4.5000000e+01
# 46         -4.4000000e+01
# 47         -4.3000000e+01
# 48         -4.2000000e+01
# 49         -4.1000000e+01
# 50         -4.0000000e+01
# 51         -3.9000000e+01
# 52         -3.8000000e+01
# 53         -3.7000000e+01
# 54         -3.6000000e+01
# 55         -3.5000000e+01
# 56         -3.4000000e+01
# 57         -3.3000000e+01
# 58         -3.2000000e+01
# 59         -3.1000000e+01
# 60         -3.0000000e+01
# 61         -2.9000000e+01
# 62         -2.8000000e+01
# 63         -2.7000000e+01
# 64         -2.6000000e+01
# 65         -2.5000000e+01
# 66         -2.4000000e+01
# 67         -2.3000000e+01
# 68         -2.2000000e+01
# 69         -2.1000000e+01
# 70         -2.0000000e+01
# 71         -1.9000000e+01
# 72         -1.8000000e+01
# 73         -1.7000000e+01
# 74         -1.6000000e+01
# 75         -1.5000000e+01
# 76         -1.4000000e+01
# 77         -1.3000000e+01
# 78         -1.2000000e+01
# 79         -1.1000000e+01
# 80         -1.0000000e+01
# 81         -9.0000000e+00
# 82         -8.0000000e+00
# 83         -7.0000000e+00
# 84         -6.0000000e+00
# 85         -5.0000000e+00
# 86         -4.0000000e+00
# 87         -3.0000000e+00
# 88         -2.0000000e+00
# 89         -1.0000000e+00
# 90          0.0000000e+00
# 91          1.0000000e+00
# 92          2.0000000e+00
# 93          3.0000000e+00
# 94          4.0000000e+00
# 95          5.0000000e+00
# 96          6.0000000e+00
# 97          7.0000000e+00
# 98                    8.0
# 99          9.0000000e+00
# 100                  10.0
# 101         1.1000000e+01
# 102         1.2000000e+01
# 103         1.3000000e+01
# 104         1.4000000e+01
# 105         1.5000000e+01
# 106         1.6000000e+01
# 107         1.7000000e+01
# 108         1.8000000e+01
# 109         1.9000000e+01
# 110         2.0000000e+01
# 111         2.1000000e+01
# 112         2.2000000e+01
# 113         2.3000000e+01
# 114         2.4000000e+01
# 115         2.5000000e+01
# 116         2.6000000e+01
# 117         2.7000000e+01
# 118         2.8000000e+01
# 119         2.9000000e+01
# 120         3.0000000e+01
# 121         3.1000000e+01
# 122         3.2000000e+01
# 123         3.3000000e+01
# 124         3.4000000e+01
# 125         3.5000000e+01
# 126         3.6000000e+01
# 127         3.7000000e+01
# 128         3.8000000e+01
# 129         3.9000000e+01
# 130         4.0000000e+01
# 131         4.1000000e+01
# 132         4.2000000e+01
# 133         4.3000000e+01
# 134         4.4000000e+01
# 135         4.5000000e+01
# 136         4.6000000e+01
# 137         4.7000000e+01
# 138         4.8000000e+01
# 139         4.9000000e+01
# 140         5.0000000e+01
# 141         5.1000000e+01
# 142         5.2000000e+01
# 143         5.3000000e+01
# 144         5.4000000e+01
# 145         5.5000000e+01
# 146         5.6000000e+01
# 147         5.7000000e+01
# 148         5.8000000e+01
# 149         5.9000000e+01
# 150         6.0000000e+01
# 151         6.1000000e+01
# 152         6.2000000e+01
# 153         6.3000000e+01
# 154         6.4000000e+01
# 155         6.5000000e+01
# 156         6.6000000e+01
# 157         6.7000000e+01
# 158         6.8000000e+01
# 159         6.9000000e+01
# 160         7.0000000e+01
# 161         7.1000000e+01
# 162         7.2000000e+01
# 163         7.3000000e+01
# 164         7.4000000e+01
# 165         7.5000000e+01
# 166         7.6000000e+01
# 167         7.7000000e+01
# 168         7.8000000e+01
# 169         7.9000000e+01
# 170         8.0000000e+01
# 171         8.1000000e+01
# 172         8.2000000e+01
# 173         8.3000000e+01
# 174         8.4000000e+01
# 175         8.5000000e+01
# 176         8.6000000e+01
# 177         8.7000000e+01
# 178         8.8000000e+01
# 179         8.9000000e+01
# 180         9.0000000e+01
# 181         9.1000000e+01

# %%
print(df_cl.columns)
# Out:
# Index(['Angle of Attack [deg]', 'Lift Coefficient Cl [-]',
#        'Lift Coefficient Cl [-].1', 'Lift Coefficient Cl [-].2',
#        'Lift Coefficient Cl [-].3', 'Lift Coefficient Cl [-].4',
#        'Lift Coefficient Cl [-].5', 'Lift Coefficient Cl [-].6',
#        'Lift Coefficient Cl [-].7'],
#       dtype='object')

# %%
df_cl.to_csv('cl.txt', index=False, header=False, sep='\t')
df_cd.to_csv('cd.txt', index=False, header=False, sep='\t')

# %%
#df2.to_csv('arquivo_final', index=False, header=False, sep='\t') ( de -180 a +180)
df_cl_1.to_csv('cl_plus.txt', index=False, header=False, sep='\t')
df_cd_1.to_csv('cd_pus.txt', index=False, header=False, sep='\t')

# %%
# paralel test ( coment )

# Example for space- or tab-delimited files
#f = pd.read_csv('data.txt', delimiter='\t')  # or use delimiter=' ' for space

# Save as CSV
#df.to_csv('data.csv', index=False)
#"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl"
#df3.to_csv('C:/Users/pedro/Downloads/Xmobots_Matlab/polares.airfoils/Clark Y/cl/cl.txt', index=False, sep='\t')
df = pd.read_csv('/kaggle/working/cl.txt',delimiter='\t')

print(df.columns)
df.head(12)
#print('/kaggle/working/cl.txt')

# %% [markdown]
# ## Writing to files

# %%
## read and transform, line to line ( coment )


#import csv
#"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl\cl_R_2e4.txt"
# Open the .txt file and read lines
#with open('"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl\cl_R_2e4.txt"', 'r') as txt_file:
#    lines = txt_file.readlines()

# Write to a .csv file
#with open('/kaggle/input/polar-try/cl_R_2e4.txt', 'w', newline='') as csv_file:
#    writer = csv.writer(csv_file)

 #   for line in lines:
 #       row = line.strip().split()  # Change .split() to .split(',') if it's comma-separated
 #       writer.writerow(row)

# %%
df2.to_csv("/kaggle/working/Combined_NOT_Flights_2022.csv", index=False)
#/kaggle/input/polar-try/cl_R_2e4.csv
#print(df2)

# %% [markdown]
# ## Dataframe basics

# %%
pd.set_option("display.max_columns", 500)

# %%
df2.head(3)

# %%
df2.tail(3)

# %%
df2.sample(3, random_state=42)

# %%
df2.sample(frac=0.000001, random_state=42)

# %%
df2.columns

# %%
df.index
# Out:
# RangeIndex(start=0, stop=385, step=1)

# %% [markdown]
# ## Dataframe summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Angle of Attack [deg]      385 non-null    object
#  1   Drag Coefficient Cd [-]    385 non-null    object
#  2   Angle of Attack [deg].1    385 non-null    object
#  3   Drag Coefficient Cd [-].1  385 non-null    object
#  4   Angle of Attack [deg].2    385 non-null    object
#  5   Drag Coefficient Cd [-].2  385 non-null    object
#  6   Angle of Attack [deg].3    385 non-null    object
#  7   Drag Coefficient Cd [-].3  385 non-null    object
#  8   Angle of Attack [deg].4    385 non-null    object
#  9   Drag Coefficient Cd [-].4  385 non-null    object
#  10  Angle of Attack [deg].5    385 non-null    float64
#  11  Drag Coefficient Cd [-].5  385 non-null    float64
#  12  Angle of Attack [deg].6    385 non-null    float64
#  13  Drag Coefficient Cd [-].6  385 non-null    float64
#  14  Angle of Attack [deg].7    385 non-null    object
#  15  Drag Coefficient Cd [-].7  385 non-null    object
#  16  Angle of Attack [deg].8    385 non-null    object
#  17  Drag Coefficient Cd [-].8  385 non-null    object
# dtypes: float64(4), object(14)
# memory usage: 54.3+ KB

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Columns: 18 entries, Angle of Attack [deg] to Drag Coefficient Cd [-].8
# dtypes: float64(4), object(14)
# memory usage: 54.3+ KB

# %%
df.describe()
# Out:
#        Angle of Attack [deg].5  Drag Coefficient Cd [-].5  \
# count               385.000000                 385.000000
# mean                  0.498701                   0.801850
# std                 101.075599                   0.626259
# min                -180.000000                   0.006000
# 25%                 -84.000000                   0.153785
# 50%                   4.000000                   0.758641
# 75%                  84.000000                   1.426280
# max                 180.000000                   1.766797
#
#        Angle of Attack [deg].6  Drag Coefficient Cd [-].6
# count               385.000000                 385.000000
# mean                  0.498701                   0.801812
# std                 101.075599                   0.626808
# min                -180.000000                   0.005840
# 25%                 -84.000000                   0.151308
# 50%                   4.000000                   0.758641
# 75%                  84.000000                   1.426466
# max                 180.000000                   1.767372

# %%
df[["Airline"]].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 df[["Airline"]].describe()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5936     if use_interval_msg:
#    5937         key = list(key)
# -> 5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Airline'], dtype='object')] are in the [columns]"

# %%
df.shape, len(df)

# %% [markdown]
# ## Subsetting Columns

# %%
df[['FlightDate', 'Airline', 'Origin']]

# %%
df[df.columns[:5]]

# %%
df[[c for c in df.columns if 'Time' in c]]

# %% [markdown]
# ## Select dtypes

# %%
df.select_dtypes('int')

# %% [markdown]
# ## Select as series vs dataframe

# %%
df['Airline']

# %%
df[['Airline']]

# %% [markdown]
# ## loc and iloc

# %%
df.iloc[1, 3]

# %%
df.iloc[:5, :5]

# %%
df.iloc[[5]]

# %%
df.iloc[:, 1]

# %%
df.iloc[:, [1, 2]]

# %%
df.loc[:, ['Airline', 'Origin']]

# %% [markdown]
# ## loc filter expressions

# %%
df.loc[df['Airline'] == 'Spirit Air Lines']

# %%
df.loc[(df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-03-30')]

# %%
df.loc[~((df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-03-30'))]

# %% [markdown]
# ## query

# %%
df.query('DepTime > 1130 and (Origin == "DRO")')

# %%
# min_time = 1130
# df.query('DepTime > @min_time and (Origin == "DRO")')  # ValueError: Expression ((DepTime) > (__pd_eval_local_min_time)) & (Series_1_0x200x4c0x3a0x6c0xbf0x7d0x00x0) has forbidden control characters.

min_time = 1130
query_expression = 'DepTime > {} and (Origin == "DRO")'.format(min_time)
df.query(query_expression)

# %% [markdown]
# ## Summary Statistics

# %%
df['DepTime'].min()

# %%
df['DepTime'].max()

# %%
df['DepTime'].mean()

# %%
df['DepTime'].std()

# %%
df['DepTime'].sum()

# %%
df['DepTime'].quantile(0.5)

# %%
df['DepTime'].quantile([0.25, 0.75])

# %% [markdown]
# ## agg

# %%
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(['mean', 'min', 'max'])

# %%
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(
    {
        'DepTime': ['min', 'max'],
        'DepDelay': ['mean'],
        'ArrTime': ['min', 'max']
    }
)

# %% [markdown]
# ## Summarize categoricals

# %%
df['Airline'].unique()

# %%
df['Airline'].nunique()

# %%
df['Airline'].value_counts()

# %%
df[['Airline', 'Origin']].value_counts()

# %%
df[['Airline', 'Origin']].value_counts().reset_index()

# %% [markdown]
# ## rank, shift, cumsum

# %%
df[['CRSDepTime']].rank(method='dense')

# %%
df[['CRSDepTime']].rank(method='first')

# %%
df[['CRSDepTime']].shift(1)

# %%
df[['CRSDepTime']].shift(-1)

# %%
df[['CRSDepTime']].shift(3, fill_value=100)

# %%
df[['CRSDepTime']].cumsum()

# %%
df[['CRSDepTime']].cummax()

# %%
df[['CRSDepTime']].cummin()

# %% [markdown]
# ## Rolling methods

# %%
df[['DepDelayMinutes']].rolling(window=5).mean()

# %% [markdown]
# ## Clip

# %%
df['DepTime'].clip(1000, 2000)

# %% [markdown]
# ## Groupby

# %%
df.groupby('Airline')[['DepDelay']].mean()

# %%
df.groupby('Airline')[['DepDelay']].agg(['mean', 'min', 'max'])

# %%
df_agg = df.groupby('Airline')[['DepDelay', 'ArrDelay']].agg(['mean', 'min', 'max'])

# %%
df_agg.columns

# %%
df_agg.columns.to_flat_index()

# %%
df_agg.columns = ["_".join(c) for c in df_agg.columns]

# %%
df_agg

# %% [markdown]
# ## New columns

# %%
df['DepTime2'] = df['DepTime'] / 60

# %%
df.head(3)

# %%
df = df.assign(DepTime3 = df['DepTime'] / 60)
df.head(3)

# %% [markdown]
# ## Sorting

# %%
df.sort_values('ArrDelay')

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay', ascending=False)

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay', ascending=False).reset_index(drop=True)

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_index()

# %% [markdown]
# ## Missing data

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].isna()

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].isna().sum()

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].dropna(subset=['ArrDelay'])

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].fillna(-999)

# %%
df['ArrDelay'].fillna(df['ArrDelay'].mean())

# %% [markdown]
# ## Concat

# %%
df1 = df.query('Airline == "Southwest Airlines Co."').copy()
df2 = df.query('Airline == "Delta Air Lines Inc."').copy()

# %%
pd.concat([df1, df2])

# %%
df_stack = pd.concat([df1, df2])

# %%
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# %%
df_side = pd.concat([df1, df2], axis=1)

# %%
df1.shape, df2.shape, df_stack.shape, df_side.shape

# %% [markdown]
# ## Merge dataframes

# %%
df1 = df.groupby(['Airline', 'FlightDate'])[['DepDelay']].mean().reset_index()
df2 = df.groupby(['Airline', 'FlightDate'])[['ArrDelay']].mean().reset_index()

# %%
df2

# %%
df1.merge(df2, how="left")

# %%
df1.merge(df2, how="right")

# %%
df1.merge(df2, how="outer")

# %% [markdown]
# ## Merge suffixes

# %%
pd.merge(df1, df2, on=['Airline', 'FlightDate'])

# %%
pd.merge(df1, df2, on=['Airline'])

# %%
pd.merge(df1, df2, on=['Airline'], suffixes=('_dep', '_arr'))

# %%
pd.merge(df1, df2, left_on=['Airline'], right_on=['Airline'])
