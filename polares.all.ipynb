# %% [markdown]
# ##Use coeficientes CL e Cd From Qblade

# %%
import pandas as pd
import sys
import csv

print(sys.version)
print('pandas version', pd.__version__)
# Out:
# 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:40:32) [GCC 12.3.0]
# pandas version 2.0.3

# %%
#/kaggle/input/polar-try/Clark Y

# %% [markdown]
# ## Reading from files ( No edit from Qblade )

# %%
df = pd.read_csv("/kaggle/input/polar-try/Clark Y/esconde_geim/all_cd.txt",delimiter='\t',skiprows=2)

#/kaggle/input/polar-try/Clark Y/esconde_geim/all_cd.txt
#df2 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_4.5e4.txt",delimiter='\t', skiprows=1, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
df3 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_1e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
df4 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cd/cd_R_4.5e4.txt",delimiter='\t', skiprows=1)
#df_temp = pd.read_csv('arquivo.csv', nrows=0)
#print(df2.columns)
#df2.head(12)
#df2['cl_next'] = df3.iloc[:, 1]

#print(df.columns)
df.head(12)

#print(df2.columns)
#df2.head(12)
#/kaggle/input/polar-try/E63
# Out:
#    Angle of Attack [deg] Drag Coefficient Cd [-] Angle of Attack [deg].1  \
# 0         -1.8000000e+02           6.0000266e-03          -1.8000000e+02
# 1         -1.7900000e+02           6.5219849e-03          -1.7900000e+02
# 2         -1.7800000e+02           8.0861580e-03          -1.7800000e+02
# 3         -1.7700000e+02           1.0689044e-02          -1.7700000e+02
# 4         -1.7600000e+02           1.4325885e-02          -1.7600000e+02
# 5         -1.7500000e+02           1.8990668e-02          -1.7500000e+02
# 6         -1.7400000e+02           2.4676139e-02          -1.7400000e+02
# 7         -1.7300000e+02           3.1373817e-02          -1.7300000e+02
# 8         -1.7200000e+02           3.9074007e-02          -1.7200000e+02
# 9         -1.7100000e+02           4.7765806e-02          -1.7100000e+02
# 10        -1.7000000e+02           5.7437137e-02          -1.7000000e+02
# 11        -1.6900000e+02           6.8074740e-02          -1.6900000e+02
#
#    Drag Coefficient Cd [-].1 Angle of Attack [deg].2  \
# 0              6.0000126e-03          -1.8000000e+02
# 1              6.5219710e-03          -1.7900000e+02
# 2              8.0861449e-03          -1.7800000e+02
# 3              1.0689033e-02          -1.7700000e+02
# 4              1.4325876e-02          -1.7600000e+02
# 5              1.8990660e-02          -1.7500000e+02
# 6              2.4676135e-02          -1.7400000e+02
# 7              3.1373817e-02          -1.7300000e+02
# 8              3.9074015e-02          -1.7200000e+02
# 9              4.7765821e-02          -1.7100000e+02
# 10             5.7437159e-02          -1.7000000e+02
# 11             6.8074770e-02          -1.6900000e+02
#
#    Drag Coefficient Cd [-].2 Angle of Attack [deg].3  \
# 0              6.0000150e-03          -1.8000000e+02
# 1              6.5219733e-03          -1.7900000e+02
# 2              8.0861468e-03          -1.7800000e+02
# 3              1.0689035e-02          -1.7700000e+02
# 4              1.4325877e-02          -1.7600000e+02
# 5              1.8990662e-02          -1.7500000e+02
# 6              2.4676135e-02          -1.7400000e+02
# 7              3.1373817e-02          -1.7300000e+02
# 8              3.9074011e-02          -1.7200000e+02
# 9              4.7765817e-02          -1.7100000e+02
# 98              9.3799997e-03                   0.007090
# 99              9.5899999e-03                   0.007310
# 100             9.8099997e-03                   0.007610
# 101             1.0100000e-02                   0.007980
# 102             1.0490000e-02                   0.008510
# 103             1.1020000e-02                   0.009140
# 104             1.1700000e-02                   0.009750
# 105             1.2410000e-02                   0.010290
# 106             1.3080000e-02                   0.010780
# 107             1.3790000e-02                   0.011290
# 108             1.4500000e-02                   0.011810
# 109             1.5230000e-02                   0.012340
# 110             1.6000001e-02                   0.012980
# 111             1.6690001e-02                   0.013930
# 112             1.7490000e-02                   0.015450
# 113             1.8630000e-02                   0.016780
# 114             2.0420000e-02                   0.018010
# 115             2.2369999e-02                   0.019500
# 116             2.4329999e-02                   0.022290
# 117             2.6440000e-02                   0.024350
# 118             2.9360000e-02                   0.026840
# 119             3.8300000e-02                   0.029990
# 120             4.3609999e-02                   0.034030
#
#      Drag Coefficient Cd [-].6 Drag Coefficient Cd [-].7
# 80                    0.013097             1.3068210e-02
# 81                    0.012857             1.2856713e-02
# 82                    0.012761             1.2761436e-02
# 83                    0.012666             1.2666257e-02
# 84                    0.012571             1.2571077e-02
# 85                    0.012476             1.2475898e-02
# 86                    0.009680             8.8499999e-03
# 87                    0.009350             8.5199997e-03
# 88                    0.008840             8.2799997e-03
# 89                    0.008570             8.0899997e-03
# 90                    0.008370             7.8800004e-03
# 91                    0.008010             7.7000000e-03
# 92                    0.007490             7.2699999e-03
# 93                    0.007200             6.8799998e-03
# 94                    0.006700             6.6300002e-03
# 95                    0.006020             6.1100000e-03
# 96                    0.005840             5.5200001e-03
# 97                    0.006050             5.5600000e-03
# 98                    0.006270             5.8400002e-03
# 99                    0.006540             6.1100000e-03
# 100                   0.006840             6.4699999e-03
# 101                   0.007310             7.0900000e-03
# 102                   0.007930             7.5800000e-03
# 103                   0.008470             7.9800002e-03
# 104                   0.008900             8.3400002e-03
# 105                   0.009330             9.0500005e-03
# 106                   0.009730             9.4799995e-03
# 107                   0.010170             9.9499999e-03
# 108                   0.010630             1.0690000e-02
# 109                   0.011150             1.1950000e-02
# 110                   0.012170             1.3040000e-02
# 111                   0.013510             1.3900000e-02
# 112                   0.014600             1.5160000e-02
# 113                   0.015570             1.7080000e-02
# 114                   0.017150             1.8300001e-02
# 115                   0.019190             1.9680001e-02
# 116                   0.020820             2.1140000e-02
# 117                   0.022830             2.2940001e-02
# 118                   0.025150             2.5160000e-02
# 119                   0.027580             2.8330000e-02
# 120                   0.030530             3.2960001e-02

# %%
print(df.columns)
# Out:
# Index(['Angle of Attack [deg]', 'Drag Coefficient Cd [-]',
#        'Drag Coefficient Cd [-].1', 'Drag Coefficient Cd [-].2',
#        'Drag Coefficient Cd [-].3', 'Drag Coefficient Cd [-].4',
#        'Drag Coefficient Cd [-].5', 'Drag Coefficient Cd [-].6',
#        'Drag Coefficient Cd [-].7'],
#       dtype='object')

# %% [markdown]
# df_cl_1 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_2e4.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
# df_cl_2 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_4.5e4.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
# df_cl_3 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_7.5e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
# df_cl_4 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_1e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
# df_cl_5 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_2.5e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
# df_cl_6 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_5e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
# df_cl_7 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_7.5e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
# df_cl_8 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_1e6.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
# df_cl_1.head(12)

# %% [markdown]
# df_cd_1 = pd.read_csv("/kaggle/input/polar-try/E63/cd/cd_R_2e4.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Drag Coefficient Cd [-]'])
# df_cd_2 = pd.read_csv("/kaggle/input/polar-try/E63/cd/cd_R_4.5e4.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Drag Coefficient Cd [-]'])
# df_cd_3 = pd.read_csv("/kaggle/input/polar-try/E63/cd/cd_R_7.5e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Drag Coefficient Cd [-]'])
# df_cd_4 = pd.read_csv("/kaggle/input/polar-try/E63/cd/cd_R_1e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Drag Coefficient Cd [-]'])
# df_cd_5 = pd.read_csv("/kaggle/input/polar-try/E63/cd/cd_R_2.5e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Drag Coefficient Cd [-]'])
# df_cd_6 = pd.read_csv("/kaggle/input/polar-try/E63/cd/cd_R_5e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Drag Coefficient Cd [-]'])
# df_cd_7 = pd.read_csv("/kaggle/input/polar-try/E63/cd/cd_R_7.5e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Drag Coefficient Cd [-]'])
# df_cd_8 = pd.read_csv("/kaggle/input/polar-try/E63/cd/cd_R_1e6.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Drag Coefficient Cd [-]'])
# #df_cd_3.head(12)

# %%
df_cl_7.head(12)

# %%
df_cl_1['cl_R_4.5e4'] = df_cl_2.iloc[:, 1]
#df_cl_1.head(12)

df_cl_1['cl_R_7.5e4'] = df_cl_3.iloc[:, 1]
df_cl_1['cl_R_1e5'] = df_cl_4.iloc[:, 1]
df_cl_1['cl_R_2.5e5'] = df_cl_5.iloc[:, 1]
df_cl_1['cl_R_5e5'] = df_cl_6.iloc[:, 1]
df_cl_1['cl_R_7.5e5'] = df_cl_7.iloc[:, 1]
df_cl_1['cl_R_1e6'] = df_cl_8.iloc[:, 1]



df_cd_1['cd_R_4.5e4'] = df_cd_2.iloc[:, 1]
df_cd_1['cd_R_7.5e4'] = df_cd_3.iloc[:, 1]
df_cd_1['cd_R_1e5']   = df_cd_4.iloc[:, 1]
df_cd_1['cd_R_2.5e5'] = df_cd_5.iloc[:, 1]
df_cd_1['cd_R_5e5']   = df_cd_6.iloc[:, 1]
df_cd_1['cd_R_7.5e5'] = df_cd_7.iloc[:, 1]
df_cd_1['cd_R_1e6']   = df_cd_8.iloc[:, 1]
#df_cd_1.columns

# %%
df_cd_1.head(12)

# %%
df_cd_1.columns.values[1] = 'cd_R_2e4'
print(df_cd_1.columns)
df_cd_1.head(12)

# %% [markdown]
# **salvando as respostas de -90 a +90 como output**

# %%
df_cl_1.iloc[90:280].to_csv('cl.txt', index=False, header=False, sep='\t')
df_cd_1.iloc[90:280].to_csv('cd.txt', index=False, header=False, sep='\t')

# %% [markdown]
# ** ( de -180 a +180) **

# %%
#df2.to_csv('arquivo_final', index=False, header=False, sep='\t') ( de -180 a +180)
df_cl_1.to_csv('cl_plus.txt', index=False, header=False, sep='\t')
df_cd_1.to_csv('cd_pus.txt', index=False, header=False, sep='\t')

# %%
# paralel test ( coment )

# Example for space- or tab-delimited files
#f = pd.read_csv('data.txt', delimiter='\t')  # or use delimiter=' ' for space

# Save as CSV
#df.to_csv('data.csv', index=False)
#"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl"
#df3.to_csv('C:/Users/pedro/Downloads/Xmobots_Matlab/polares.airfoils/Clark Y/cl/cl.txt', index=False, sep='\t')
df = pd.read_csv('/kaggle/working/cl.txt',delimiter='\t')

print(df.columns)
df.head(12)
#print('/kaggle/working/cl.txt')

# %% [markdown]
# ## Writing to files

# %%
## read and transform, line to line ( coment )


#import csv
#"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl\cl_R_2e4.txt"
# Open the .txt file and read lines
#with open('"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl\cl_R_2e4.txt"', 'r') as txt_file:
#    lines = txt_file.readlines()

# Write to a .csv file
#with open('/kaggle/input/polar-try/cl_R_2e4.txt', 'w', newline='') as csv_file:
#    writer = csv.writer(csv_file)

 #   for line in lines:
 #       row = line.strip().split()  # Change .split() to .split(',') if it's comma-separated
 #       writer.writerow(row)

# %%
df2.to_csv("/kaggle/working/Combined_NOT_Flights_2022.csv", index=False)
#/kaggle/input/polar-try/cl_R_2e4.csv
#print(df2)

# %% [markdown]
# ## Dataframe basics

# %%
pd.set_option("display.max_columns", 500)

# %%
df2.head(3)

# %%
df2.tail(3)

# %%
df2.sample(3, random_state=42)

# %%
df2.sample(frac=0.000001, random_state=42)

# %%
df2.columns

# %%
df.index

# %% [markdown]
# ## Dataframe summary

# %%
df.info()

# %%
df.info(verbose=False)

# %%
df.describe()

# %%
df[["Airline"]].describe()

# %%
df.shape, len(df)

# %% [markdown]
# ## Subsetting Columns

# %%
df[['FlightDate', 'Airline', 'Origin']]

# %%
df[df.columns[:5]]

# %%
df[[c for c in df.columns if 'Time' in c]]

# %% [markdown]
# ## Select dtypes

# %%
df.select_dtypes('int')

# %% [markdown]
# ## Select as series vs dataframe

# %%
df['Airline']

# %%
df[['Airline']]

# %% [markdown]
# ## loc and iloc

# %%
df.iloc[1, 3]

# %%
df.iloc[:5, :5]

# %%
df.iloc[[5]]

# %%
df.iloc[:, 1]

# %%
df.iloc[:, [1, 2]]

# %%
df.loc[:, ['Airline', 'Origin']]

# %% [markdown]
# ## loc filter expressions

# %%
df.loc[df['Airline'] == 'Spirit Air Lines']

# %%
df.loc[(df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-03-30')]

# %%
df.loc[~((df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-03-30'))]

# %% [markdown]
# ## query

# %%
df.query('DepTime > 1130 and (Origin == "DRO")')

# %%
# min_time = 1130
# df.query('DepTime > @min_time and (Origin == "DRO")')  # ValueError: Expression ((DepTime) > (__pd_eval_local_min_time)) & (Series_1_0x200x4c0x3a0x6c0xbf0x7d0x00x0) has forbidden control characters.

min_time = 1130
query_expression = 'DepTime > {} and (Origin == "DRO")'.format(min_time)
df.query(query_expression)

# %% [markdown]
# ## Summary Statistics

# %%
df['DepTime'].min()

# %%
df['DepTime'].max()

# %%
df['DepTime'].mean()

# %%
df['DepTime'].std()

# %%
df['DepTime'].sum()

# %%
df['DepTime'].quantile(0.5)

# %%
df['DepTime'].quantile([0.25, 0.75])

# %% [markdown]
# ## agg

# %%
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(['mean', 'min', 'max'])

# %%
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(
    {
        'DepTime': ['min', 'max'],
        'DepDelay': ['mean'],
        'ArrTime': ['min', 'max']
    }
)

# %% [markdown]
# ## Summarize categoricals

# %%
df['Airline'].unique()

# %%
df['Airline'].nunique()

# %%
df['Airline'].value_counts()

# %%
df[['Airline', 'Origin']].value_counts()

# %%
df[['Airline', 'Origin']].value_counts().reset_index()

# %% [markdown]
# ## rank, shift, cumsum

# %%
df[['CRSDepTime']].rank(method='dense')

# %%
df[['CRSDepTime']].rank(method='first')

# %%
df[['CRSDepTime']].shift(1)

# %%
df[['CRSDepTime']].shift(-1)

# %%
df[['CRSDepTime']].shift(3, fill_value=100)

# %%
df[['CRSDepTime']].cumsum()

# %%
df[['CRSDepTime']].cummax()

# %%
df[['CRSDepTime']].cummin()

# %% [markdown]
# ## Rolling methods

# %%
df[['DepDelayMinutes']].rolling(window=5).mean()

# %% [markdown]
# ## Clip

# %%
df['DepTime'].clip(1000, 2000)

# %% [markdown]
# ## Groupby

# %%
df.groupby('Airline')[['DepDelay']].mean()

# %%
df.groupby('Airline')[['DepDelay']].agg(['mean', 'min', 'max'])

# %%
df_agg = df.groupby('Airline')[['DepDelay', 'ArrDelay']].agg(['mean', 'min', 'max'])

# %%
df_agg.columns

# %%
df_agg.columns.to_flat_index()

# %%
df_agg.columns = ["_".join(c) for c in df_agg.columns]

# %%
df_agg

# %% [markdown]
# ## New columns

# %%
df['DepTime2'] = df['DepTime'] / 60

# %%
df.head(3)

# %%
df = df.assign(DepTime3 = df['DepTime'] / 60)
df.head(3)

# %% [markdown]
# ## Sorting

# %%
df.sort_values('ArrDelay')

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay', ascending=False)

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay', ascending=False).reset_index(drop=True)

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_index()

# %% [markdown]
# ## Missing data

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].isna()

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].isna().sum()

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].dropna(subset=['ArrDelay'])

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].fillna(-999)

# %%
df['ArrDelay'].fillna(df['ArrDelay'].mean())

# %% [markdown]
# ## Concat

# %%
df1 = df.query('Airline == "Southwest Airlines Co."').copy()
df2 = df.query('Airline == "Delta Air Lines Inc."').copy()

# %%
pd.concat([df1, df2])

# %%
df_stack = pd.concat([df1, df2])

# %%
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# %%
df_side = pd.concat([df1, df2], axis=1)

# %%
df1.shape, df2.shape, df_stack.shape, df_side.shape

# %% [markdown]
# ## Merge dataframes

# %%
df1 = df.groupby(['Airline', 'FlightDate'])[['DepDelay']].mean().reset_index()
df2 = df.groupby(['Airline', 'FlightDate'])[['ArrDelay']].mean().reset_index()

# %%
df2

# %%
df1.merge(df2, how="left")

# %%
df1.merge(df2, how="right")

# %%
df1.merge(df2, how="outer")

# %% [markdown]
# ## Merge suffixes

# %%
pd.merge(df1, df2, on=['Airline', 'FlightDate'])

# %%
pd.merge(df1, df2, on=['Airline'])

# %%
pd.merge(df1, df2, on=['Airline'], suffixes=('_dep', '_arr'))

# %%
pd.merge(df1, df2, left_on=['Airline'], right_on=['Airline'])
