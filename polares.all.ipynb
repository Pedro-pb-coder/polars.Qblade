# %% [markdown]
# ## Use coeficientes CL e Cd From Qblade

# %%
import pandas as pd
import sys
import csv

print(sys.version)
print('pandas version', pd.__version__)
# Out:
# 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:40:32) [GCC 12.3.0]
# pandas version 2.0.3

# %%
 # /kaggle/input/polar-try/E63 # V11

# %% [markdown]
# ## Reading from files ( No edit from Qblade )

# %%
## Carregar banco de dados 

df_cd = pd.read_csv("/kaggle/input/polar-try/MH112/esconde_geim/all_cd.txt",delimiter='\t',skiprows=2)
df_cl = pd.read_csv("/kaggle/input/polar-try/MH112/esconde_geim/all_cl.txt",delimiter='\t',skiprows=2)
#/kaggle/input/polar-try/Clark Y/esconde_geim/all_cd.txt
#df2 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_4.5e4.txt",delimiter='\t', skiprows=1, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
#df3 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cl/cl_R_1e5.txt",delimiter='\t', skiprows=2, usecols=['Angle of Attack [deg]', 'Lift Coefficient Cl [-]'])
#df4 = pd.read_csv("/kaggle/input/polar-try/Clark Y/cd/cd_R_4.5e4.txt",delimiter='\t', skiprows=1)
#df_temp = pd.read_csv('arquivo.csv', nrows=0)
#print(df2.columns)
#df2.head(12)
#df2['cl_next'] = df3.iloc[:, 1]

#print(df.columns)
#df_cl.head(6)
#df_cd.head(12)

print('done')
#df2.head(12)
#/kaggle/input/polar-try/E63
# Out:
# done

# %%
# Garante que pandas mostre todas as linhas e colunas sem cortar

#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_colwidth', None)

pd.reset_option('display.max_rows')
pd.reset_option('display.max_colwidth')

print(df_cl.iloc[:, [0]])
# Out:
#     Angle of Attack [deg]
# 0          -1.8000000e+02
# 1          -1.7900000e+02
# 2          -1.7800000e+02
# 3          -1.7700000e+02
# 4          -1.7600000e+02
# ..                    ...
# 356         1.7700000e+02
# 357         1.7800000e+02
# 358         1.7900000e+02
# 359         1.8000000e+02
# 360                   END
#
# [361 rows x 1 columns]

# %%
# Remover colunas desnecessárias 

columns_to_drop_cd = [
    'Angle of Attack [deg].1',
    'Angle of Attack [deg].2',
    'Angle of Attack [deg].3',
    'Angle of Attack [deg].4',
    'Angle of Attack [deg].5',
    'Angle of Attack [deg].6',
    'Angle of Attack [deg].7',
    'Angle of Attack [deg].8',
    'Drag Coefficient Cd [-].8'
]
#Drag Coefficient Cd [-].8
columns_to_drop_cl = [
    'Angle of Attack [deg].1',
    'Angle of Attack [deg].2',
    'Angle of Attack [deg].3',
    'Angle of Attack [deg].4',
    'Angle of Attack [deg].5',
    'Angle of Attack [deg].6',
    'Angle of Attack [deg].7',
    'Angle of Attack [deg].8',
    'Lift Coefficient Cl [-].8'
]
 
df_cl = df_cl.drop(columns=columns_to_drop_cl, errors='ignore')
df_cd = df_cd.drop(columns=columns_to_drop_cd, errors='ignore')

# Remover linhas desnecessárias 
df_cl = df_cl[df_cl.iloc[:, 0] != 'END']
df_cd = df_cd[df_cd.iloc[:, 0] != 'END']

print( 'done')
# Out:
# done

# %%
# testar de vieram certo
#df_cl.head(360)
df_cd.head(400)
# Out:
#     Angle of Attack [deg] Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 0          -1.8000000e+02           6.0000047e-03             6.0000103e-03
# 1          -1.7900000e+02           6.5114717e-03             6.5114773e-03
# 2          -1.7800000e+02           8.0429707e-03             8.0429763e-03
# 3          -1.7700000e+02           1.0589224e-02             1.0589229e-02
# 4          -1.7600000e+02           1.4143730e-02             1.4143734e-02
# ..                    ...                     ...                       ...
# 355         1.7600000e+02           1.4261780e-02             1.4237002e-02
# 356         1.7700000e+02           1.0670174e-02             1.0642597e-02
# 357         1.7800000e+02           8.1056003e-03             8.0761146e-03
# 358         1.7900000e+02           6.5678540e-03             6.5373210e-03
# 359         1.8000000e+02           6.0554659e-03             6.0247174e-03
#
#     Drag Coefficient Cd [-].2 Drag Coefficient Cd [-].3  \
# 0               6.0000136e-03             6.0000261e-03
# 1               6.5114805e-03             6.5114931e-03
# 2               8.0429791e-03             8.0429921e-03
# 3               1.0589232e-02             1.0589244e-02
# 4               1.4143737e-02             1.4143747e-02
# ..                        ...                       ...
# 355             8.0549140e-03                       END
# 356             6.5155113e-03                       END
# 357             6.0028969e-03                       END
# 358                       END                       END
# 359                       END                       END
#
#      Drag Coefficient Cd [-].4  Drag Coefficient Cd [-].5  \
# 0                     0.006000                   0.006000
# 1                     0.006512                   0.006512
# 2                     0.008043                   0.008043
# 3                     0.010589                   0.010589
# 4                     0.014144                   0.014144
# ..                         ...                        ...
# 355                   0.018848                   0.018853
# 356                   0.014225                   0.014231
# 357                   0.010629                   0.010635
# 358                   0.008062                   0.008069
# 359                   0.006523                   0.006529
#
#      Drag Coefficient Cd [-].6  Drag Coefficient Cd [-].7
# 0                     0.006000                   0.006000
# 1                     0.006512                   0.006512
# 2                     0.008043                   0.008043
# 3                     0.010589                   0.010589
# 4                     0.014144                   0.014144
# ..                         ...                        ...
# 355                   0.018852                   0.018855
# 356                   0.014229                   0.014233
# 357                   0.010634                   0.010638
# 358                   0.008067                   0.008071
# 359                   0.006528                   0.006532
#
# [360 rows x 9 columns]

# %%
# remover pontas desnecessárias 

# aoenas 1 vez 

df_cl = df_cl.iloc[90:-90].reset_index(drop=True)
df_cd = df_cd.iloc[90:-90].reset_index(drop=True)

print('done')
# Out:
# done

# %%
# testar se removera certo

df_cd.head(181)
#df_cd.head(181)
# Out:
#     Angle of Attack [deg] Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 0          -9.0000000e+01           1.5798624e+00             1.5798587e+00
# 1          -8.9000000e+01           1.5793992e+00             1.5793953e+00
# 2          -8.8000000e+01           1.5780104e+00             1.5780064e+00
# 3          -8.7000000e+01           1.5756977e+00             1.5756934e+00
# 4          -8.6000000e+01           1.5724634e+00             1.5724590e+00
# ..                    ...                     ...                       ...
# 175         8.6000000e+01           1.7731502e+00             1.7757102e+00
# 176         8.7000000e+01           1.7772912e+00             1.7798953e+00
# 177         8.8000000e+01           1.7803189e+00             1.7829611e+00
# 178         8.9000000e+01           1.7822292e+00             1.7849040e+00
# 179         9.0000000e+01           1.7830199e+00             1.7857217e+00
#
#     Drag Coefficient Cd [-].2 Drag Coefficient Cd [-].3  \
# 0               1.5798562e+00             1.5798455e+00
# 1               1.5793927e+00             1.5793815e+00
# 2               1.5780036e+00             1.5779918e+00
# 3               1.5756905e+00             1.5756781e+00
# 4               1.5724559e+00             1.5724428e+00
# ..                        ...                       ...
# 175             1.7903939e+00             1.7711564e+00
# 176             1.7921385e+00             1.7640501e+00
# 177             1.7927597e+00             1.7558534e+00
# 178             1.7922570e+00             1.7465770e+00
# 179             1.7906313e+00             1.7362332e+00
#
#      Drag Coefficient Cd [-].4  Drag Coefficient Cd [-].5  \
# 0                     1.579833                   1.579833
# 1                     1.579368                   1.579368
# 2                     1.577978                   1.577978
# 3                     1.575663                   1.575663
# 4                     1.572427                   1.572427
# ..                         ...                        ...
# 175                   1.772592                   1.768436
# 176                   1.777923                   1.773915
# 177                   1.782134                   1.778269
# 178                   1.785219                   1.781493
# 179                   1.787175                   1.783584
#
#      Drag Coefficient Cd [-].6  Drag Coefficient Cd [-].7
# 0                     1.579833                   1.579833
# 1                     1.579368                   1.579368
# 2                     1.577978                   1.577978
# 3                     1.575663                   1.575663
# 4                     1.572427                   1.572427
# ..                         ...                        ...
# 175                   1.769318                   1.766780
# 176                   1.774768                   1.772321
# 177                   1.779095                   1.776736
# 178                   1.782291                   1.780018
# 179                   1.784356                   1.782166
#
# [180 rows x 9 columns]

# %% [markdown]
# podemos ver assim quantas linhas faltam

# %% [markdown]
# ## Obter linhas que faltam

# %%
df_cd.iloc[80:91]



# falta E63
# 9 dgr , linha 99 --> igual a de baixo
# 13 dgr , linha 102 --> igual a de baixo
# 14 dgr , linha 103 --> igual a de cima

# falta MH112
# -1 dgr linha 89 --> igual a de baixo
# Out:
#    Angle of Attack [deg] Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 80        -1.0000000e+01           5.5738010e-02             5.4682028e-02
# 81        -9.0000000e+00           4.6277460e-02             4.4979513e-02
# 82        -8.0000000e+00           3.7753470e-02             3.6156423e-02
# 83        -7.0000000e+00           3.0185727e-02             2.8258367e-02
# 84        -6.0000000e+00           2.3608394e-02             2.1449041e-02
# 85        -5.0000000e+00           1.8099811e-02             1.6180895e-02
# 86        -4.0000000e+00           1.1609000e-01             1.3162000e-01
# 87        -3.0000000e+00           1.1121000e-01             1.2465000e-01
# 88        -2.0000000e+00           1.1171000e-01             1.1546000e-01
# 89         0.0000000e+00           8.7140001e-02             1.0527000e-01
# 90         1.0000000e+00           8.0550000e-02             7.5999998e-02
#
#    Drag Coefficient Cd [-].2 Drag Coefficient Cd [-].3  \
# 80             5.1869459e-02             1.7550966e-02
# 81             4.1217156e-02             1.4171769e-02
# 82             3.1263988e-02             1.3487304e-02
# 83             2.2532923e-02             1.3289837e-02
# 84             1.6296571e-02             1.3105575e-02
# 85             1.3448297e-02             1.2921313e-02
# 86             1.0959000e-01             9.2560001e-02
# 87             9.6139997e-02             4.7219999e-02
# 88             5.6850001e-02             4.4170000e-02
# 89             5.8880001e-02             5.1309999e-02
# 90             5.9450001e-02             5.5909999e-02
#
#     Drag Coefficient Cd [-].4  Drag Coefficient Cd [-].5  \
# 80                   0.013843                   0.013843
# 81                   0.013658                   0.013658
# 82                   0.013474                   0.013474
# 83                   0.013290                   0.013290
# 84                   0.013106                   0.013106
# 85                   0.012921                   0.012921
# 86                   0.018630                   0.012030
# 87                   0.016380                   0.010840
# 88                   0.014670                   0.010140
# 89                   0.014490                   0.009950
# 90                   0.014270                   0.009730
#
#     Drag Coefficient Cd [-].6  Drag Coefficient Cd [-].7
# 80                   0.013843                   0.013843
# 81                   0.013658                   0.013658
# 82                   0.013474                   0.013474
# 83                   0.013290                   0.013290
# 84                   0.013106                   0.013106
# 85                   0.012921                   0.012921
# 86                   0.010380                   0.009120
# 87                   0.009230                   0.008590
# 88                   0.008890                   0.008060
# 89                   0.008490                   0.007930
# 90                   0.008480                   0.007750

# %% [markdown]
# ## TRATAMENTO PARA MH112

# %%
## alterações em CL

# alterar incorreto cl -1 
#import pandas as pd
# add a line between line 88 and 89 that is the same as line 88

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:89]                      # inclui até a linha 88
duplicate_row = df_cl.iloc[[88]].copy()   # linha 88 (como DataFrame)
bottom = df_cl.iloc[89:]                  # da linha 89 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau -1 
df_cl.iloc[89, 0] = -1.0000000e+00

# show 

df_cl.iloc[85:91]
# Out:
#    Angle of Attack [deg] Lift Coefficient Cl [-] Lift Coefficient Cl [-].1  \
# 85        -5.0000000e+00          -6.5643489e-01            -9.5213997e-01
# 86        -4.0000000e+00          -3.8800001e-02            -4.3570000e-01
# 87        -3.0000000e+00          -4.9899999e-02            -4.6500000e-01
# 88        -2.0000000e+00          -2.3639999e-01            -4.1409999e-01
# 89                  -1.0          -2.3639999e-01            -4.1409999e-01
# 90         0.0000000e+00          -2.3710001e-01            -3.6579999e-01
#
#    Lift Coefficient Cl [-].2 Lift Coefficient Cl [-].3  \
# 85            -1.0529431e+00            -2.2633512e-01
# 86            -1.8030000e-01            -3.6800001e-02
# 87            -1.1620000e-01             2.6220000e-01
# 88             2.8180000e-01             4.0380001e-01
# 89             2.8180000e-01             4.0380001e-01
# 90             3.4720001e-01             6.0699999e-01
#
#     Lift Coefficient Cl [-].4  Lift Coefficient Cl [-].5  \
# 85                   0.330229                   0.365133
# 86                   0.436800                   0.470600
# 87                   0.544500                   0.587100
# 88                   0.664800                   0.699900
# 89                   0.664800                   0.699900
# 90                   0.778500                   0.814800
#
#     Lift Coefficient Cl [-].6  Lift Coefficient Cl [-].7
# 85                   0.373742                   0.381076
# 86                   0.479700                   0.485300
# 87                   0.594500                   0.598600
# 88                   0.708700                   0.714600
# 89                   0.708700                   0.714600
# 90                   0.822200                   0.824300

# %%
## alterações em CD

# alterar incorreto cl -1 
#import pandas as pd
# add a line between line 88 and 89 that is the same as line 88

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:89]                      # inclui até a linha 88
duplicate_row = df_cd.iloc[[88]].copy()   # linha 88 (como DataFrame)
bottom = df_cd.iloc[89:]                  # da linha 89 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau -1 
df_cd.iloc[89, 0] = -1.0000000e+00

# show 

df_cd.iloc[85:91]
# Out:
#    Angle of Attack [deg] Drag Coefficient Cd [-] Drag Coefficient Cd [-].1  \
# 85        -5.0000000e+00           1.8099811e-02             1.6180895e-02
# 86        -4.0000000e+00           1.1609000e-01             1.3162000e-01
# 87        -3.0000000e+00           1.1121000e-01             1.2465000e-01
# 88        -2.0000000e+00           1.1171000e-01             1.1546000e-01
# 89                  -1.0           1.1171000e-01             1.1546000e-01
# 90         0.0000000e+00           8.7140001e-02             1.0527000e-01
#
#    Drag Coefficient Cd [-].2 Drag Coefficient Cd [-].3  \
# 85             1.3448297e-02             1.2921313e-02
# 86             1.0959000e-01             9.2560001e-02
# 87             9.6139997e-02             4.7219999e-02
# 88             5.6850001e-02             4.4170000e-02
# 89             5.6850001e-02             4.4170000e-02
# 90             5.8880001e-02             5.1309999e-02
#
#     Drag Coefficient Cd [-].4  Drag Coefficient Cd [-].5  \
# 85                   0.012921                   0.012921
# 86                   0.018630                   0.012030
# 87                   0.016380                   0.010840
# 88                   0.014670                   0.010140
# 89                   0.014670                   0.010140
# 90                   0.014490                   0.009950
#
#     Drag Coefficient Cd [-].6  Drag Coefficient Cd [-].7
# 85                   0.012921                   0.012921
# 86                   0.010380                   0.009120
# 87                   0.009230                   0.008590
# 88                   0.008890                   0.008060
# 89                   0.008890                   0.008060
# 90                   0.008490                   0.007930

# %% [markdown]
# ## TRATAMENTO PARA MH116

# %%
## alterações em CL

# alterar incorreto cl 9 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:99]                      # inclui até a linha 98
duplicate_row = df_cl.iloc[[98]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[99:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cl.iloc[99, 0] = 9.0000000e+00

# alterar incorreto cl 10
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:100]                      # inclui até a linha 90
duplicate_row = df_cl.iloc[[100]].copy()   # linha 100 (como DataFrame)
bottom = df_cl.iloc[100:]                  # da linha 100 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cl.iloc[100, 0] = 1.0000000e+01




# show 

df_cl.iloc[95:110]

# %%
## alterações em CD

# alterar incorreto cd 9 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:99]                      # inclui até a linha 98
duplicate_row = df_cd.iloc[[98]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[99:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[99, 0] = 9.0000000e+00

# alterar incorreto cl 10
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:100]                      # incdui até a linha 90
duplicate_row = df_cd.iloc[[100]].copy()   # linha 100 (como DataFrame)
bottom = df_cd.iloc[100:]                  # da linha 100 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[100, 0] = 1.0000000e+01




# show 

df_cd.iloc[95:110]

# %% [markdown]
# ## TRATAMENTO PARA E63

# %%
## alterações em CL

# alterar incorreto cl 9 

# add a line between line 98 and 99 that is the same as line 98


# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:99]                      # inclui até a linha 98
duplicate_row = df_cl.iloc[[98]].copy()   # linha 98 (como DataFrame)
bottom = df_cl.iloc[99:]                  # da linha 99 em diante

# Concatenar tudo  ( top + copy + botton) 
      #( linha faltante assume o valor da linha copiada,e entra no seu lugar)
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

# alterar valor do grau 9 
df_cl.iloc[99, 0] = 9.0000000e+00

## 
# alterar incorreto cl 13 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:103]                      # inclui até a linha 97
duplicate_row = df_cl.iloc[[102]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[103:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cl.iloc[103, 0] = 1.3000000e+01

##

# alterar incorreto cl 14 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:104]                      # inclui até a linha 97
duplicate_row = df_cl.iloc[[104]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[104:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cl.iloc[104, 0] = 1.4000000e+01


# show 

df_cl.iloc[95:110]

# %%
## alterações em CD

# alterar incorreto cd 9 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:99]                      # inclui até a linha 98
duplicate_row = df_cd.iloc[[98]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[99:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[99, 0] = 9.0000000e+00

## 
# alterar incorreto cd 13 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:103]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[102]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[103:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[103, 0] = 1.3000000e+01

##

# alterar incorreto cd 14 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:104]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[104]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[104:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[104, 0] = 1.4000000e+01


# show 

df_cd.iloc[95:110]

# %%
# Garante que pandas mostre todas as linhas e colunas sem cortar

#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_colwidth', None)

pd.reset_option('display.max_rows')
pd.reset_option('display.max_colwidth')

print(df_cd.iloc[:, [0]])

# %% [markdown]
# ## Save files

# %%
# Save files

df_cl.to_csv('cl.txt', index=False, header=False, sep='\t')
df_cd.to_csv('cd.txt', index=False, header=False, sep='\t')
print('done')

# %% [markdown]
# ## Rascunhos

# %% [markdown]
# uma vez que a maioreia dos exemplos clonando linhas apresenta erro na interpolação, faz-se necessario modificar o método de tratamento das matrizes de cl e cd. sendo que o erro das tratadas aparece da mesma forma , mesmo que os númerod de dgr permanecam em sequencia correta de -90 a +90

# %%
df = df_cl
if len(df) < 89:
    raise ValueError("O arquivo CSV precisa ter pelo menos 89 linhas para inserir na posição 88.")
# Pega as linhas acima e abaixo da linha 88
linha_acima = df.iloc[87]
linha_abaixo = df.iloc[88]
# Calcula a média (interpolação linear)
linha_interpolada = (linha_acima + linha_abaixo) / 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/computation/expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 8
#       6 linha_abaixo = df.iloc[88]
#       7 # Calcula a média (interpolação linear)
# ----> 8 linha_interpolada = (linha_acima + linha_abaixo) / 2
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:6112, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
#    6111     self, other = ops.align_method_SERIES(self, other)
# -> 6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:232, in arithmetic_op(left, right, op)
#     228     _bool_arith_check(op, left, right)
#     230     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     231     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 232     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     234 return res_values
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:178, in _na_arithmetic_op(left, right, op, is_cmp)
#     172 except TypeError:
#     173     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     174         # For object dtype, fallback to a masked operation (only operating
#     175         #  on the non-missing values)
#     176         # Don't do this for comparisons, as that will handle complex numbers
#     177         #  incorrectly, see GH#32047
# --> 178         result = _masked_arith_op(left, right, op)
#     179     else:
#     180         raise
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:135, in _masked_arith_op(x, y, op)
#     132         mask = np.where(y == 1, False, mask)
#     134     if mask.any():
# --> 135         result[mask] = op(xrav[mask], y)
#     137 np.putmask(result, ~mask, np.nan)
#     138 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
## fazer interpolação entre os valores das colunas seguintes 
#da de cima e da de baixo ao inves de coloar a de baixo ou de cima arbitratiamente 

#import pandas as pd

# Caminho do arquivo CSV
#arquivo_csv = 'arquivo_csv'

# Lê o arquivo CSV em um DataFrame
#df = pd.read_csv(arquivo_csv)
df = df_cl
# Verifica se há pelo menos 89 linhas
if len(df) < 89:
    raise ValueError("O arquivo CSV precisa ter pelo menos 89 linhas para inserir na posição 88.")

# Pega as linhas acima e abaixo da linha 88
linha_acima = df.iloc[87]
linha_abaixo = df.iloc[88]

# Calcula a média (interpolação linear)
linha_interpolada = (linha_acima + linha_abaixo) / 2

# Insere a nova linha no índice 88
df_parte1 = df.iloc[:88]
df_parte2 = df.iloc[88:]

# Concatena as partes com a nova linha no meio
df_novo = pd.concat([df_parte1, pd.DataFrame([linha_interpolada]), df_parte2], ignore_index=True)

# Salva de volta no CSV (sobrescrevendo)
df_novo.to_csv('arquivo_modificado.csv', index=False)

print("Linha interpolada inserida com sucesso na linha 88.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/computation/expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 21
#      18 linha_abaixo = df.iloc[88]
#      20 # Calcula a média (interpolação linear)
# ---> 21 linha_interpolada = (linha_acima + linha_abaixo) / 2
#      23 # Insere a nova linha no índice 88
#      24 df_parte1 = df.iloc[:88]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:6112, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
#    6111     self, other = ops.align_method_SERIES(self, other)
# -> 6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:232, in arithmetic_op(left, right, op)
#     228     _bool_arith_check(op, left, right)
#     230     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     231     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 232     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     234 return res_values
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:178, in _na_arithmetic_op(left, right, op, is_cmp)
#     172 except TypeError:
#     173     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     174         # For object dtype, fallback to a masked operation (only operating
#     175         #  on the non-missing values)
#     176         # Don't do this for comparisons, as that will handle complex numbers
#     177         #  incorrectly, see GH#32047
# --> 178         result = _masked_arith_op(left, right, op)
#     179     else:
#     180         raise
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:135, in _masked_arith_op(x, y, op)
#     132         mask = np.where(y == 1, False, mask)
#     134     if mask.any():
# --> 135         result[mask] = op(xrav[mask], y)
#     137 np.putmask(result, ~mask, np.nan)
#     138 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
df_cl.iloc[95:110]

# %%
# alterar incorreto cd 9 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:99]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[98]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[99:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cd.iloc[99, 0] = 9.0000000e+00
# show 

df_cd.iloc[95:105]

# %%
# template codigo de adicionar/ copiar linhas 
#import pandas as pd
# add a line between line 97 and 98 that is the same as line 97

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:99]                      # inclui até a linha 98
duplicate_row = df_cl.iloc[[98]].copy()   # linha 98 (como DataFrame)
bottom = df_cl.iloc[99:]                  # da linha 99 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)
# alterar valor do grau 9 
df_cl.iloc[99, 0] = 9.0000000e+00
# show 

df_cl.iloc[95:105]

# %%
import pandas as pd

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df.iloc[:98]                      # inclui até a linha 97
duplicate_row = df.iloc[[97]].copy()   # linha 97 (como DataFrame)
bottom = df.iloc[98:]                  # da linha 98 em diante

# Concatenar tudo
df = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

# %%
df_cl.iloc[99, 0] = 9.0000000e+00

# %%
df_cl.iloc[95:105]

# %%
#corect missing values  cl 9

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:100]                      # inclui até a linha 97
duplicate_row = df_cl.iloc[[99]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[100:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cl.iloc[99, 0] = 9.0000000e+00
#df_cl
print('done')

# %%
df_cl.iloc[80:121]

# %%
# template codigo de adicionar/ copiar linhas 
import pandas as pd

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df.iloc[:98]                      # inclui até a linha 97
duplicate_row = df.iloc[[97]].copy()   # linha 97 (como DataFrame)
bottom = df.iloc[98:]                  # da linha 98 em diante

# Concatenar tudo
df = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

# %%
#corect missing values cl 10

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cl.iloc[:100]                      # inclui até a linha 97
duplicate_row = df_cl.iloc[[99]].copy()   # linha 97 (como DataFrame)
bottom = df_cl.iloc[100:]                  # da linha 98 em diante

# Concatenar tudo
df_cl = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cl.iloc[100, 0] = 1.0000000e+01
#df_cl
print('done')

# %%
#corect missing values  cd 8

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:98]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[97]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[98:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cd.iloc[98, 0] = 9.0000000e+00
#df_cld
print('done')

# %%
#corect missing values cd 10

# Supondo que 'df' é o seu DataFrame

# Separar o topo, a linha a duplicar, e o restante
top = df_cd.iloc[:100]                      # inclui até a linha 97
duplicate_row = df_cd.iloc[[99]].copy()   # linha 97 (como DataFrame)
bottom = df_cd.iloc[100:]                  # da linha 98 em diante

# Concatenar tudo
df_cd = pd.concat([top, duplicate_row, bottom]).reset_index(drop=True)

print('done')
df_cd.iloc[100, 0] = 1.0000000e+01
#df_cl
print('done')

# %%
df_cl.iloc[95:110]

# %%
df_cd.iloc[95:110]

# %%
df_cd.head(190)

# %%
df_cl.head(180)

# %%
# Garante que pandas mostre todas as linhas e colunas sem cortar
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
print(df_cl.iloc[:, [0]])

# %%
print(df_cl.iloc[:, [0]])

# %%
print(df_cl.columns)

# %%
df_cl.to_csv('cl.txt', index=False, header=False, sep='\t')
df_cd.to_csv('cd.txt', index=False, header=False, sep='\t')
print('done')

# %%
#df2.to_csv('arquivo_final', index=False, header=False, sep='\t') ( de -180 a +180)
df_cl_1.to_csv('cl_plus.txt', index=False, header=False, sep='\t')
df_cd_1.to_csv('cd_pus.txt', index=False, header=False, sep='\t')

# %%
# paralel test ( coment )

# Example for space- or tab-delimited files
#f = pd.read_csv('data.txt', delimiter='\t')  # or use delimiter=' ' for space

# Save as CSV
#df.to_csv('data.csv', index=False)
#"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl"
#df3.to_csv('C:/Users/pedro/Downloads/Xmobots_Matlab/polares.airfoils/Clark Y/cl/cl.txt', index=False, sep='\t')
df = pd.read_csv('/kaggle/working/cl.txt',delimiter='\t')

print(df.columns)
df.head(12)
#print('/kaggle/working/cl.txt')

# %% [markdown]
# ## Writing to files

# %%
## read and transform, line to line ( coment )


#import csv
#"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl\cl_R_2e4.txt"
# Open the .txt file and read lines
#with open('"C:\Users\pedro\Downloads\Xmobots_Matlab\polares.airfoils\Clark Y\cl\cl_R_2e4.txt"', 'r') as txt_file:
#    lines = txt_file.readlines()

# Write to a .csv file
#with open('/kaggle/input/polar-try/cl_R_2e4.txt', 'w', newline='') as csv_file:
#    writer = csv.writer(csv_file)

 #   for line in lines:
 #       row = line.strip().split()  # Change .split() to .split(',') if it's comma-separated
 #       writer.writerow(row)

# %%
df2.to_csv("/kaggle/working/Combined_NOT_Flights_2022.csv", index=False)
#/kaggle/input/polar-try/cl_R_2e4.csv
#print(df2)

# %% [markdown]
# ## Dataframe basics

# %%
pd.set_option("display.max_columns", 500)

# %%
df2.head(3)

# %%
df2.tail(3)

# %%
df2.sample(3, random_state=42)

# %%
df2.sample(frac=0.000001, random_state=42)

# %%
df2.columns

# %%
df.index

# %% [markdown]
# ## Dataframe summary

# %%
df.info()

# %%
df.info(verbose=False)

# %%
df.describe()

# %%
df[["Airline"]].describe()

# %%
df.shape, len(df)

# %% [markdown]
# ## Subsetting Columns

# %%
df[['FlightDate', 'Airline', 'Origin']]

# %%
df[df.columns[:5]]

# %%
df[[c for c in df.columns if 'Time' in c]]

# %% [markdown]
# ## Select dtypes

# %%
df.select_dtypes('int')

# %% [markdown]
# ## Select as series vs dataframe

# %%
df['Airline']

# %%
df[['Airline']]

# %% [markdown]
# ## loc and iloc

# %%
df.iloc[1, 3]

# %%
df.iloc[:5, :5]

# %%
df.iloc[[5]]

# %%
df.iloc[:, 1]

# %%
df.iloc[:, [1, 2]]

# %%
df.loc[:, ['Airline', 'Origin']]

# %% [markdown]
# ## loc filter expressions

# %%
df.loc[df['Airline'] == 'Spirit Air Lines']

# %%
df.loc[(df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-03-30')]

# %%
df.loc[~((df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-03-30'))]

# %% [markdown]
# ## query

# %%
df.query('DepTime > 1130 and (Origin == "DRO")')

# %%
# min_time = 1130
# df.query('DepTime > @min_time and (Origin == "DRO")')  # ValueError: Expression ((DepTime) > (__pd_eval_local_min_time)) & (Series_1_0x200x4c0x3a0x6c0xbf0x7d0x00x0) has forbidden control characters.

min_time = 1130
query_expression = 'DepTime > {} and (Origin == "DRO")'.format(min_time)
df.query(query_expression)

# %% [markdown]
# ## Summary Statistics

# %%
df['DepTime'].min()

# %%
df['DepTime'].max()

# %%
df['DepTime'].mean()

# %%
df['DepTime'].std()

# %%
df['DepTime'].sum()

# %%
df['DepTime'].quantile(0.5)

# %%
df['DepTime'].quantile([0.25, 0.75])

# %% [markdown]
# ## agg

# %%
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(['mean', 'min', 'max'])

# %%
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(
    {
        'DepTime': ['min', 'max'],
        'DepDelay': ['mean'],
        'ArrTime': ['min', 'max']
    }
)

# %% [markdown]
# ## Summarize categoricals

# %%
df['Airline'].unique()

# %%
df['Airline'].nunique()

# %%
df['Airline'].value_counts()

# %%
df[['Airline', 'Origin']].value_counts()

# %%
df[['Airline', 'Origin']].value_counts().reset_index()

# %% [markdown]
# ## rank, shift, cumsum

# %%
df[['CRSDepTime']].rank(method='dense')

# %%
df[['CRSDepTime']].rank(method='first')

# %%
df[['CRSDepTime']].shift(1)

# %%
df[['CRSDepTime']].shift(-1)

# %%
df[['CRSDepTime']].shift(3, fill_value=100)

# %%
df[['CRSDepTime']].cumsum()

# %%
df[['CRSDepTime']].cummax()

# %%
df[['CRSDepTime']].cummin()

# %% [markdown]
# ## Rolling methods

# %%
df[['DepDelayMinutes']].rolling(window=5).mean()

# %% [markdown]
# ## Clip

# %%
df['DepTime'].clip(1000, 2000)

# %% [markdown]
# ## Groupby

# %%
df.groupby('Airline')[['DepDelay']].mean()

# %%
df.groupby('Airline')[['DepDelay']].agg(['mean', 'min', 'max'])

# %%
df_agg = df.groupby('Airline')[['DepDelay', 'ArrDelay']].agg(['mean', 'min', 'max'])

# %%
df_agg.columns

# %%
df_agg.columns.to_flat_index()

# %%
df_agg.columns = ["_".join(c) for c in df_agg.columns]

# %%
df_agg

# %% [markdown]
# ## New columns

# %%
df['DepTime2'] = df['DepTime'] / 60

# %%
df.head(3)

# %%
df = df.assign(DepTime3 = df['DepTime'] / 60)
df.head(3)

# %% [markdown]
# ## Sorting

# %%
df.sort_values('ArrDelay')

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay', ascending=False)

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay', ascending=False).reset_index(drop=True)

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].sort_index()

# %% [markdown]
# ## Missing data

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].isna()

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].isna().sum()

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].dropna(subset=['ArrDelay'])

# %%
df[['FlightDate', 'Airline', 'ArrDelay']].fillna(-999)

# %%
df['ArrDelay'].fillna(df['ArrDelay'].mean())

# %% [markdown]
# ## Concat

# %%
df1 = df.query('Airline == "Southwest Airlines Co."').copy()
df2 = df.query('Airline == "Delta Air Lines Inc."').copy()

# %%
pd.concat([df1, df2])

# %%
df_stack = pd.concat([df1, df2])

# %%
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# %%
df_side = pd.concat([df1, df2], axis=1)

# %%
df1.shape, df2.shape, df_stack.shape, df_side.shape

# %% [markdown]
# ## Merge dataframes

# %%
df1 = df.groupby(['Airline', 'FlightDate'])[['DepDelay']].mean().reset_index()
df2 = df.groupby(['Airline', 'FlightDate'])[['ArrDelay']].mean().reset_index()

# %%
df2

# %%
df1.merge(df2, how="left")

# %%
df1.merge(df2, how="right")

# %%
df1.merge(df2, how="outer")

# %% [markdown]
# ## Merge suffixes

# %%
pd.merge(df1, df2, on=['Airline', 'FlightDate'])

# %%
pd.merge(df1, df2, on=['Airline'])

# %%
pd.merge(df1, df2, on=['Airline'], suffixes=('_dep', '_arr'))

# %%
pd.merge(df1, df2, left_on=['Airline'], right_on=['Airline'])
